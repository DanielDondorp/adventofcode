# %%
import numpy as np
import functools #feel like we are doing to be caching
from collections import deque
import aocd
from z3 import *

# %%
test_data = """[.##.] (3) (1,3) (2) (2,3) (0,2) (0,1) {3,5,4,7}
[...#.] (0,2,3,4) (2,3) (0,4) (0,1,2) (1,2,3,4) {7,5,12,7,2}
[.###.#] (0,1,2,3,4) (0,3,4) (0,1,2,4,5) (1,2) {10,11,11,5,10,5}"""

# %%
data = aocd.get_data()

# %%
def str_to_bits(string):
    string = "".join(["0" if x == "." else "1" for x in string[1:-1]])
    n = int(string, 2)
    return n, len(string)

# %%
x = str_to_bits("[.##.]")

# %%
button = 1<<3 | 1<<1

# %%
button
# Out:
# 10

# %%
bin(button)
# Out:
# '0b1010'

# %%
bin(6 | 8)
# Out:
# '0b1110'

# %%
x = 0
x | (3<<1)
# Out:
# 6

# %%
# I need to convert a button tuple to bits that can be used in an XOR operation that is a button press. 
# There is some left-right stuff between bitshifting vs the representation of the machines indicator lights.
def convert_button(button, n_bits):
    mask = 0
    for b in button:
        mask |= 1 << (n_bits - 1 - b)  # left index → right index
    return mask

# %%
def parse_data(data):
    machines = []
    for line in data.split('\n'):
        linesplit = line.split(" ")
        final_state = linesplit[0]
        final_state, n_bits = str_to_bits(final_state)
        joltages = linesplit[-1]
        buttons = linesplit[1:-1]
        buttons = [tuple(map(int, button.strip("()").split(","))) for button in buttons]
        buttons = [convert_button(button, n_bits) for button in buttons]
        machines.append({"final_state": final_state, "buttons":buttons, "n_bits":n_bits, "joltages":joltages})
    return machines

# %%
machines = parse_data(test_data)

# %%
def press_buttons(start, final_state, buttons, n_bits):
    mask = (1 << n_bits) - 1

    queue = deque([(start, 0)])
    visited = {start}

    while queue:
        state, steps = queue.popleft()

        if state == final_state:
            return steps

        for b in buttons:
            new_state = (state ^ b) & mask   # Restrict to bit_width
            if new_state not in visited:
                visited.add(new_state)
                queue.append((new_state, steps + 1))

    return None

# %%
m = machines[0]

# %%
for m in machines:
    print(m)
    print(press_buttons(0, m["final_state"], m["buttons"], m["n_bits"]))
# Out:
# {'final_state': 6, 'buttons': [1, 5, 2, 3, 10, 12], 'n_bits': 4, 'joltages': '{3,5,4,7}'}
# 2
# {'final_state': 2, 'buttons': [23, 6, 17, 28, 15], 'n_bits': 5, 'joltages': '{7,5,12,7,2}'}
# 3
# {'final_state': 29, 'buttons': [62, 38, 59, 24], 'n_bits': 6, 'joltages': '{10,11,11,5,10,5}'}
# 2

# %%
machines = parse_data(data)
total = 0
for m in machines:
    total += press_buttons(0, m["final_state"], m["buttons"], m["n_bits"])

# %%
total
# Out:
# 486

# %%
#part two: we need a new push button thing and a new final state and everything for the joltages

# %%
def get_joltages(joltages):
    joltages = joltages[1:-1].split(",")
    joltages = tuple([int(j) for j in joltages])
    return joltages, len(joltages)

# %%
# def convert_button_joltage_mode(button, n_bits):
#     mask = [0 for _ in range(n_bits)]
#     for b in button:
#         mask[b]+=1
#     return tuple(mask)

def convert_button_joltage_mode(button, n_bits):
    return tuple(1 if i in button else 0 for i in range(n_bits))

# %%
convert_button_joltage_mode((4,1), 5)
# Out:
# (0, 1, 0, 0, 1)

# %%
n_bits = 5
button = (0,2,3,4)
convert_button_joltage_mode(button, n_bits)
# Out:
# (1, 0, 1, 1, 1)

# %%
get_joltages('{10,11,11,5,10,5}')
# Out:
# ((10, 11, 11, 5, 10, 5), 6)

# %%
def parse_data2(data):
    machines = []
    for line in data.split('\n'):
        linesplit = line.split(" ")
        final_state = linesplit[0]
        # final_state, n_bits = str_to_bits(final_state)
        joltages = linesplit[-1]
        joltages, n_bits = get_joltages(joltages)
        buttons = linesplit[1:-1]
        buttons = [tuple(map(int, button.strip("()").split(","))) for button in buttons]
        buttons = [convert_button_joltage_mode(button, n_bits) for button in buttons]
        machines.append({"final_state": final_state, "buttons":buttons, "n_bits":n_bits, "joltages":tuple(joltages)})
    return machines

# %%
test_machines = parse_data2(test_data)

# %%
j = test_machines[0]["joltages"][0]

# %%
b = test_machines[0]["buttons"][1]

# %%
def press_buttons2(start, final_state, buttons):
    queue = deque([(start, 0)])
    visited = {start}

    while queue:
        state, steps = queue.popleft()

        if state == final_state:
            return steps

        for b in buttons:
            new_state = tuple(si + bi for si, bi in zip(state, b))
            # new_state = (state ^ b) & mask   # Restrict to bit_width
            if any(ns > fs for ns, fs in zip(new_state, final_state)):
                continue
            if new_state not in visited:
                visited.add(new_state)
                queue.append((new_state, steps + 1))

    return None

# %%
def press_buttons2(start, final_state, buttons):
    n_bits = len(final_state)
    queue = deque([(start, 0)])
    visited = {start}

    while queue:
        state, steps = queue.popleft()

        if state == final_state:
            return steps

        for b in buttons:
            new_state = tuple(si + bi for si, bi in zip(state, b)) #increment the joltage counters

            # if any joltage counter exceeds the target, this is not a combination we can use
            if any(ns > fs for ns, fs in zip(new_state, final_state)):
                continue

            if new_state not in visited:
                visited.add(new_state)
                queue.append((new_state, steps + 1))

    return None

# %%
total = 0
for i, m in enumerate(test_machines):
    start = tuple([0]*m["n_bits"])
    bpresses = press_buttons2(start, m["joltages"], m["buttons"])
    # print(f"final_state = {m['joltages']}, buttons = {m['buttons']}")
    # print(f"Press {bpresses} times for machine {i}")
    total += bpresses
print(total)
# Out:
# 33

# %%
machines = parse_data2(data)

# %%
def solve_joltage_z3(target, buttons):
    n_buttons = len(buttons)
    n_bits = len(target)

    # integer variables for button press counts
    xs = [Int(f"x{i}") for i in range(n_buttons)]

    solver = Optimize()

    # non-negative integers
    for x in xs:
        solver.add(x >= 0)

    # add one equation per counter
    for bit in range(n_bits):
        solver.add(
            Sum(xs[i] * buttons[i][bit] for i in range(n_buttons)) == target[bit]
        )

    # objective: minimize total button presses
    total_presses = Sum(xs)
    solver.minimize(total_presses)

    if solver.check() != sat:
        return None

    model = solver.model()
    presses = [model[x].as_long() for x in xs]
    return presses, sum(presses)

# %%
total = 0
for i, m in enumerate(machines):
    start = tuple([0]*m["n_bits"])
    # print(f"final_state = {m['joltages']}, buttons = {m['buttons']}")
    bpresses, npresses = solve_joltage_z3(m["joltages"], m["buttons"])
    
    print(f"Press {bpresses} times for macihne {i}")
    total += npresses
print(total)
# Out:
# Press [20, 16, 5, 13, 8, 14, 11] times for macihne 0
# Press [21, 0, 9, 22, 16, 9] times for macihne 1
# Press [9, 0, 0, 17, 8, 200] times for macihne 2
# Press [6, 9, 0, 5] times for macihne 3
# Press [0, 13, 1, 7, 6, 0, 18, 5, 14] times for macihne 4
# Press [13, 17, 5, 0] times for macihne 5
# Press [1, 9, 16, 143, 6, 12, 8, 0, 1, 14, 6] times for macihne 6
# Press [7, 12, 18, 0] times for macihne 7
# Press [13, 5, 2, 20, 6, 1, 18] times for macihne 8
# Press [4, 0, 28, 20, 11, 1, 15, 9, 21] times for macihne 9
# Press [12, 17, 20, 11, 2] times for macihne 10
# Press [13, 4, 11, 0, 11, 19] times for macihne 11
# Press [2, 16, 21, 15, 25, 11, 11, 6, 0, 13, 4] times for macihne 12
# Press [19, 19, 2, 18, 6] times for macihne 13
# Press [0, 2, 12, 20, 16, 20] times for macihne 14
# Press [0, 16, 5, 0, 12, 38, 1, 9, 2, 10, 14, 28, 8] times for macihne 15
# Press [129, 15, 19, 12, 4, 20] times for macihne 16
# Press [14, 4, 4, 19, 8, 8, 16, 117] times for macihne 17
# Press [10, 13, 11, 22, 2, 8, 1, 2, 8] times for macihne 18
# Press [7, 19, 10, 15] times for macihne 19
# Press [8, 20, 1, 13, 2] times for macihne 20
# Press [6, 6, 1, 129] times for macihne 21
# Press [5, 8, 12, 10, 2] times for macihne 22
# Press [9, 3, 17, 0, 20, 0, 196] times for macihne 23
# Press [5, 13, 11] times for macihne 24
# Press [15, 20] times for macihne 25
# Press [11, 6, 12, 1, 11, 20] times for macihne 26
# Press [7, 7, 7, 7] times for macihne 27
# Press [17, 0, 25, 6, 19, 11, 19, 14] times for macihne 28
# Press [6, 8, 0, 39, 0, 20, 10] times for macihne 29
# Press [0, 28, 21, 1, 3, 0, 0, 18] times for macihne 30
# Press [19, 17, 8, 11] times for macihne 31
# Press [14, 3, 13, 14] times for macihne 32
# Press [3, 20, 19, 1, 7, 19, 7] times for macihne 33
# Press [0, 11, 0, 146, 2, 11, 12, 10, 20] times for macihne 34
# Press [4, 17, 17, 6, 11, 6, 19] times for macihne 35
# Press [2, 0, 14, 2, 17, 8, 7] times for macihne 36
# Press [2, 9, 24, 19, 0] times for macihne 37
# Press [19, 17, 114, 13, 15] times for macihne 121
# Press [5, 0, 20, 1, 14, 1, 20, 1] times for macihne 122
# Press [6, 3, 20, 0, 153, 15, 20, 8, 16] times for macihne 123
# Press [18, 2, 19, 2] times for macihne 124
# Press [10, 8, 16, 5, 3, 7, 18, 3] times for macihne 125
# Press [2, 10] times for macihne 126
# Press [16, 4] times for macihne 127
# Press [14, 11, 12, 0, 14, 20, 12, 1] times for macihne 128
# Press [18, 192, 14, 0] times for macihne 129
# Press [14, 14, 20, 115, 0, 5] times for macihne 130
# Press [0, 6, 19, 15, 4, 11, 136, 5, 0] times for macihne 131
# Press [1, 31, 0, 0, 10, 19] times for macihne 132
# Press [0, 22, 2, 122, 29, 17, 22, 0, 11] times for macihne 133
# Press [15, 4, 7, 0, 5, 21, 22, 15, 8] times for macihne 134
# Press [4, 0, 15, 15, 24, 4, 7] times for macihne 135
# Press [13, 0, 20, 11, 19, 17, 12, 4] times for macihne 136
# Press [3, 14, 2, 0, 13, 21] times for macihne 137
# Press [4, 8, 14] times for macihne 138
# Press [16, 10, 11, 25, 3, 14, 3, 2, 7] times for macihne 139
# Press [19, 1, 16] times for macihne 140
# Press [15, 12, 15, 0, 13] times for macihne 141
# Press [4, 18, 11, 24, 0, 3] times for macihne 142
# Press [13, 14, 1, 3, 13, 0] times for macihne 143
# Press [0, 12, 18, 22, 6, 2, 3] times for macihne 144
# Press [17, 14, 13] times for macihne 145
# Press [18, 17, 8, 8, 3, 8] times for macihne 146
# Press [8, 9, 10, 9, 19, 12, 7, 16, 21, 0] times for macihne 147
# Press [8, 121, 19] times for macihne 148
# Press [21, 4, 23, 3, 0, 12, 23, 0] times for macihne 149
# Press [13, 8, 8, 1, 120, 7, 7] times for macihne 150
# Press [18, 20, 19, 12, 10, 7, 20, 10, 12, 7] times for macihne 151
# Press [141, 4, 6, 2, 17, 9, 0, 5] times for macihne 152
# Press [0, 0, 3, 190, 15, 19] times for macihne 153
# Press [13, 0, 19, 15, 15, 4, 0, 17] times for macihne 154
# Press [0, 3, 2, 20, 13, 12, 9] times for macihne 155
# Press [8, 3, 20, 23, 1, 15, 0, 3, 10, 3, 5, 8] times for macihne 156
# Press [0, 18, 7, 1, 0, 7, 4] times for macihne 157
# Press [5, 11, 14, 8] times for macihne 158
# Press [16, 8, 5, 159, 6, 17, 4, 1] times for macihne 159
# Press [2, 18, 3, 14, 0, 15, 0, 18, 3, 9] times for macihne 160
# Press [0, 5, 136, 0, 29] times for macihne 161
# Press [3, 18, 15, 2, 20, 21, 2, 0] times for macihne 162
# Press [86, 4, 4, 0, 13, 14, 28] times for macihne 163
# Press [11, 2, 8, 19, 0, 2, 19, 11, 13, 7, 10, 0] times for macihne 164
# Press [27, 7, 3, 19, 18, 0, 19, 10, 6] times for macihne 165
# 17820

# %%
total
