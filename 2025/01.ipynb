# %% [markdown]
# ## Advent of Code 2025, 1

# %%
import aocd

# %%
data = aocd.get_data()

# %%
with open("puzzle_input.txt", "w") as f:
    f.write(data)

# %%
data = data.split("\n")

# %% [markdown]
# Ok, our dial start point is 50, and we parse the list of instructions. We need a rollover function that handles when we pass through zero, and aggregate locations for every step.

# %%
test_data = """L68
L30
R48
L5
R60
L55
L1
L99
R14
L82"""

# %%
test_data = test_data.split("\n")

# %%
def rollover(x: int):
    if x > 99:
        return x-100
    elif x < 0:
        return (100 + x) # adding the negative is the same as substracting
    else:
        return x

# %%
def do_instruction(loc, instruction):
    direction = instruction[0]
    amount = int(instruction[1:])
    while amount > 100:
        amount -= 100
    
    if direction == "L":
        loc -= amount
    elif direction == "R": 
        loc += amount
    real_loc = rollover(loc)
    print(f"The dial is rotated {instruction} to point at {real_loc}")
    return real_loc

# %%
do_instruction(100, "L6")
# Out:
# The dial is rotated L6 to point at 94
# 94

# %%
do_instruction(1, "L450")
# Out:
# The dial is rotated L450 to point at 51
# 51

# %%
def open_safe(data, start_position):
    sequence = [start_position]
    loc = start_position
    n_zeros = 0
    print(f"The dial starts at {loc}")
    for instruction in data:
        loc = do_instruction(loc, instruction)
        sequence.append(loc)
        if loc == 0:
            n_zeros+=1
    print(f"we had {n_zeros} zeros")
    return sequence, n_zeros

# %%
seq = open_safe(test_data, 50)
seq.count(0)
# Out:
# The dial starts at 50
# The dial is rotated L68 to point at 82
# The dial is rotated L30 to point at 52
# The dial is rotated R48 to point at 0
# The dial is rotated L5 to point at 95
# The dial is rotated R60 to point at 55
# The dial is rotated L55 to point at 0
# The dial is rotated L1 to point at 99
# The dial is rotated L99 to point at 0
# The dial is rotated R14 to point at 14
# The dial is rotated L82 to point at 32
# we had 3 zeros
# 0

# %%
seq = open_safe(data, 50)
seq.count(0)
# Out:
# The dial starts at 50
# The dial is rotated L1 to point at 49
# The dial is rotated R43 to point at 92
# The dial is rotated R6 to point at 98
# The dial is rotated R50 to point at 48
# The dial is rotated R47 to point at 95
# The dial is rotated R18 to point at 13
# The dial is rotated L12 to point at 1
# The dial is rotated L21 to point at 80
# The dial is rotated R21 to point at 1
# The dial is rotated R38 to point at 39
# The dial is rotated R15 to point at 54
# The dial is rotated R1 to point at 55
# The dial is rotated L19 to point at 36
# The dial is rotated R36 to point at 72
# The dial is rotated L33 to point at 39
# The dial is rotated R25 to point at 64
# The dial is rotated L6 to point at 58
# The dial is rotated R25 to point at 83
# The dial is rotated L7 to point at 76
# The dial is rotated L44 to point at 32
# The dial is rotated R16 to point at 48
# The dial is rotated L43 to point at 5
# The dial is rotated R27 to point at 32
# The dial is rotated L26 to point at 6
# The dial is rotated R17 to point at 23
# The dial is rotated R32 to point at 55
# The dial is rotated R49 to point at 4
# The dial is rotated L39 to point at 65
# The dial is rotated R22 to point at 87
# The dial is rotated L1 to point at 86
# The dial is rotated L10 to point at 76
# The dial is rotated R24 to point at 0
# The dial is rotated L23 to point at 77
# The dial is rotated R10 to point at 87
# The dial is rotated R13 to point at 0
# The dial is rotated L34 to point at 66
# The dial is rotated L34 to point at 32
# The dial is rotated L32 to point at 0
# The dial is rotated R2 to point at 2
# The dial is rotated L14 to point at 88
# The dial is rotated L26 to point at 62
# The dial is rotated L46 to point at 16
# The dial is rotated L42 to point at 74
# The dial is rotated R35 to point at 9
# The dial is rotated R21 to point at 30
# The dial is rotated R38 to point at 68
# The dial is rotated L8 to point at 60
# The dial is rotated L15 to point at 45
# The dial is rotated L29 to point at 16
# The dial is rotated L52 to point at 64
# The dial is rotated L10 to point at 54
# The dial is rotated L54 to point at 0
# The dial is rotated R7 to point at 7
# The dial is rotated R35 to point at 42
# The dial is rotated L16 to point at 26
# The dial is rotated L99 to point at 27
# The dial is rotated L60 to point at 67
# The dial is rotated R33 to point at 0
# The dial is rotated L38 to point at 62
# The dial is rotated L62 to point at 0
# The dial is rotated L5 to point at 95
# The dial is rotated L42 to point at 53
# The dial is rotated L53 to point at 0
# The dial is rotated R33 to point at 33
# The dial is rotated L68 to point at 65
# The dial is rotated L27 to point at 38
# The dial is rotated R19 to point at 57
# The dial is rotated L57 to point at 0
# The dial is rotated R36 to point at 36
# The dial is rotated R64 to point at 0
# The dial is rotated L27 to point at 73
# The dial is rotated R84 to point at 57
# The dial is rotated R32 to point at 89
# The dial is rotated R11 to point at 0
# The dial is rotated L39 to point at 61
# The dial is rotated L22 to point at 39
# The dial is rotated L11 to point at 28
# The dial is rotated R72 to point at 0
# The dial is rotated R78 to point at 78
# The dial is rotated L3 to point at 75
# The dial is rotated L75 to point at 0
# The dial is rotated L52 to point at 48
# The dial is rotated R71 to point at 19
# The dial is rotated R81 to point at 0
# The dial is rotated R59 to point at 59
# The dial is rotated L73 to point at 86
# The dial is rotated R62 to point at 48
# The dial is rotated L57 to point at 91
# The dial is rotated L56 to point at 35
# The dial is rotated L99 to point at 36
# The dial is rotated R64 to point at 0
# The dial is rotated R63 to point at 63
# The dial is rotated R64 to point at 27
# The dial is rotated L77 to point at 50
# The dial is rotated L50 to point at 0
# The dial is rotated R57 to point at 57
# The dial is rotated R43 to point at 0
# The dial is rotated R86 to point at 86
# The dial is rotated L86 to point at 0
# The dial is rotated R9 to point at 9
# The dial is rotated L9 to point at 0
# The dial is rotated R95 to point at 95
# The dial is rotated R430 to point at 25
# The dial is rotated L5 to point at 20
# The dial is rotated R27 to point at 47
# The dial is rotated R86 to point at 33
# The dial is rotated R67 to point at 0
# The dial is rotated L97 to point at 3
# The dial is rotated L29 to point at 74
# The dial is rotated L993 to point at 81
# The dial is rotated L14 to point at 67
# The dial is rotated L27 to point at 40
# The dial is rotated R21 to point at 61
# The dial is rotated L205 to point at 56
# The dial is rotated R913 to point at 69
# The dial is rotated R74 to point at 43
# The dial is rotated R57 to point at 0
# The dial is rotated R63 to point at 63
# The dial is rotated L754 to point at 9
# The dial is rotated R791 to point at 0
# The dial is rotated L21 to point at 79
# The dial is rotated L28 to point at 51
# The dial is rotated R91 to point at 42
# The dial is rotated L63 to point at 79
# The dial is rotated L79 to point at 0
# The dial is rotated R61 to point at 61
# The dial is rotated R61 to point at 22
# The dial is rotated L622 to point at 0
# The dial is rotated L58 to point at 42
# The dial is rotated L69 to point at 73
# The dial is rotated R879 to point at 52
# The dial is rotated L64 to point at 88
# The dial is rotated L718 to point at 70
# The dial is rotated L23 to point at 47
# The dial is rotated L47 to point at 0
# The dial is rotated R26 to point at 26
# The dial is rotated R74 to point at 0
# The dial is rotated R30 to point at 30
# The dial is rotated R46 to point at 76
# The dial is rotated R74 to point at 50
# The dial is rotated R850 to point at 0
# The dial is rotated R53 to point at 53
# The dial is rotated L775 to point at 78
# The dial is rotated L78 to point at 0
# The dial is rotated R8 to point at 8
# The dial is rotated L21 to point at 87
# The dial is rotated R713 to point at 0
# The dial is rotated L95 to point at 5
# The dial is rotated L27 to point at 78
# The dial is rotated R37 to point at 15
# The dial is rotated L9 to point at 6
# The dial is rotated L36 to point at 70
# The dial is rotated R10 to point at 80
# The dial is rotated L96 to point at 84
# The dial is rotated R34 to point at 18
# The dial is rotated L27 to point at 91
# The dial is rotated L36 to point at 55
# The dial is rotated R45 to point at 0
# The dial is rotated R33 to point at 33
# The dial is rotated L93 to point at 40
# The dial is rotated R60 to point at 0
# The dial is rotated L97 to point at 3
# The dial is rotated R3 to point at 6
# The dial is rotated R94 to point at 0
# The dial is rotated R8 to point at 8
# The dial is rotated R50 to point at 58
# The dial is rotated R67 to point at 25
# The dial is rotated R975 to point at 0
# The dial is rotated R83 to point at 83
# The dial is rotated L27 to point at 56
# The dial is rotated L42 to point at 14
# The dial is rotated R86 to point at 0
# The dial is rotated R904 to point at 4
# The dial is rotated L30 to point at 74
# The dial is rotated L81 to point at 93
# The dial is rotated R7 to point at 0
# The dial is rotated L43 to point at 57
# The dial is rotated R612 to point at 69
# The dial is rotated L67 to point at 2
# The dial is rotated L7 to point at 95
# The dial is rotated R45 to point at 40
# The dial is rotated R63 to point at 3
# The dial is rotated R97 to point at 0
# The dial is rotated R41 to point at 41
# The dial is rotated R29 to point at 70
# The dial is rotated L224 to point at 46
# The dial is rotated R56 to point at 2
# The dial is rotated L38 to point at 64
# The dial is rotated L64 to point at 0
# The dial is rotated R63 to point at 63
# The dial is rotated L21 to point at 42
# The dial is rotated L94 to point at 48
# The dial is rotated R52 to point at 0
# The dial is rotated L61 to point at 39
# The dial is rotated L39 to point at 0
# The dial is rotated R892 to point at 92
# The dial is rotated L92 to point at 0
# The dial is rotated R775 to point at 75
# The dial is rotated L28 to point at 47
# The dial is rotated R91 to point at 38
# The dial is rotated R70 to point at 8
# The dial is rotated R87 to point at 95
# The dial is rotated L52 to point at 43
# The dial is rotated R57 to point at 0
# The dial is rotated R97 to point at 97
# The dial is rotated L27 to point at 70
# The dial is rotated L97 to point at 73
# The dial is rotated L673 to point at 0
# The dial is rotated R44 to point at 44
# The dial is rotated R63 to point at 7
# The dial is rotated L96 to point at 11
# The dial is rotated L7 to point at 4
# The dial is rotated L36 to point at 68
# The dial is rotated R2 to point at 70
# The dial is rotated R25 to point at 95
# The dial is rotated R44 to point at 39
# The dial is rotated L54 to point at 85
# The dial is rotated L85 to point at 0
# The dial is rotated L89 to point at 11
# The dial is rotated L61 to point at 50
# The dial is rotated R50 to point at 0
# The dial is rotated R17 to point at 17
# The dial is rotated L35 to point at 82
# The dial is rotated L382 to point at 0
# The dial is rotated R67 to point at 67
# The dial is rotated L928 to point at 39
# The dial is rotated L12 to point at 27
# The dial is rotated L553 to point at 74
# The dial is rotated R26 to point at 0
# The dial is rotated R7 to point at 7
# The dial is rotated R93 to point at 0
# The dial is rotated L10 to point at 90
# The dial is rotated R10 to point at 0
# The dial is rotated R92 to point at 92
# The dial is rotated R257 to point at 49
# The dial is rotated L5 to point at 44
# The dial is rotated R72 to point at 16
# The dial is rotated R84 to point at 0
# The dial is rotated L98 to point at 2
# The dial is rotated L2 to point at 0
# The dial is rotated L823 to point at 77
# The dial is rotated R85 to point at 62
# The dial is rotated L50 to point at 12
# The dial is rotated L412 to point at 0
# The dial is rotated L80 to point at 20
# The dial is rotated R227 to point at 47
# The dial is rotated L354 to point at 93
# The dial is rotated L93 to point at 0
# The dial is rotated L4 to point at 96
# The dial is rotated L796 to point at 0
# The dial is rotated L834 to point at 66
# The dial is rotated R62 to point at 28
# The dial is rotated L903 to point at 25
# The dial is rotated L46 to point at 79
# The dial is rotated L79 to point at 0
# The dial is rotated R428 to point at 28
# The dial is rotated L28 to point at 0
# The dial is rotated L20 to point at 80
# The dial is rotated L139 to point at 41
# The dial is rotated L41 to point at 0
# The dial is rotated R82 to point at 82
# The dial is rotated R18 to point at 0
# The dial is rotated R87 to point at 87
# The dial is rotated R99 to point at 86
# The dial is rotated R14 to point at 0
# The dial is rotated R970 to point at 70
# The dial is rotated R30 to point at 0
# The dial is rotated L58 to point at 42
# The dial is rotated L54 to point at 88
# The dial is rotated L29 to point at 59
# The dial is rotated L54 to point at 5
# The dial is rotated L5 to point at 0
# The dial is rotated R43 to point at 43
# The dial is rotated L685 to point at 58
# The dial is rotated R542 to point at 0
# The dial is rotated R618 to point at 18
# The dial is rotated R482 to point at 0
# The dial is rotated L536 to point at 64
# The dial is rotated L43 to point at 21
# The dial is rotated R36 to point at 57
# The dial is rotated R27 to point at 84
# The dial is rotated L84 to point at 0
# The dial is rotated R37 to point at 37
# The dial is rotated L14 to point at 23
# The dial is rotated L14 to point at 9
# The dial is rotated L73 to point at 36
# The dial is rotated R5 to point at 41
# The dial is rotated L41 to point at 0
# The dial is rotated L21 to point at 79
# The dial is rotated L779 to point at 0
# The dial is rotated R39 to point at 39
# The dial is rotated R61 to point at 0
# The dial is rotated L99 to point at 1
# The dial is rotated L58 to point at 43
# The dial is rotated L484 to point at 59
# The dial is rotated R3 to point at 62
# The dial is rotated L36 to point at 26
# The dial is rotated R37 to point at 63
# The dial is rotated L99 to point at 64
# The dial is rotated L64 to point at 0
# The dial is rotated R94 to point at 94
# The dial is rotated R34 to point at 28
# The dial is rotated L28 to point at 0
# The dial is rotated L9 to point at 91
# The dial is rotated R45 to point at 36
# The dial is rotated L23 to point at 13
# The dial is rotated L65 to point at 48
# The dial is rotated R91 to point at 39
# The dial is rotated R61 to point at 0
# The dial is rotated L880 to point at 20
# The dial is rotated L16 to point at 4
# The dial is rotated L104 to point at 0
# The dial is rotated R76 to point at 76
# The dial is rotated R23 to point at 99
# The dial is rotated R1 to point at 0
# The dial is rotated R149 to point at 49
# The dial is rotated L47 to point at 2
# The dial is rotated R70 to point at 72
# The dial is rotated R14 to point at 86
# The dial is rotated L16 to point at 70
# The dial is rotated R81 to point at 51
# The dial is rotated R49 to point at 0
# The dial is rotated L33 to point at 67
# The dial is rotated L67 to point at 0
# The dial is rotated R677 to point at 77
# The dial is rotated L77 to point at 0
# The dial is rotated L420 to point at 80
# The dial is rotated R120 to point at 0
# The dial is rotated R59 to point at 59
# The dial is rotated L59 to point at 0
# The dial is rotated R90 to point at 90
# The dial is rotated L47 to point at 43
# The dial is rotated L37 to point at 6
# The dial is rotated L6 to point at 0
# The dial is rotated R71 to point at 71
# The dial is rotated L71 to point at 0
# The dial is rotated R82 to point at 82
# The dial is rotated R78 to point at 60
# The dial is rotated R40 to point at 0
# The dial is rotated R39 to point at 39
# The dial is rotated L54 to point at 85
# The dial is rotated R82 to point at 67
# The dial is rotated L9 to point at 58
# The dial is rotated R2 to point at 60
# The dial is rotated R41 to point at 1
# The dial is rotated R99 to point at 0
# The dial is rotated R9 to point at 9
# The dial is rotated R91 to point at 0
# The dial is rotated L69 to point at 31
# The dial is rotated R69 to point at 0
# The dial is rotated L41 to point at 59
# The dial is rotated R41 to point at 0
# The dial is rotated L482 to point at 18
# The dial is rotated R19 to point at 37
# The dial is rotated R388 to point at 25
# The dial is rotated R75 to point at 0
# The dial is rotated L38 to point at 62
# The dial is rotated L62 to point at 0
# The dial is rotated L5 to point at 95
# The dial is rotated R5 to point at 0
# The dial is rotated L46 to point at 54
# The dial is rotated R93 to point at 47
# The dial is rotated R645 to point at 92
# The dial is rotated R8 to point at 0
# The dial is rotated R1 to point at 1
# The dial is rotated L1 to point at 0
# The dial is rotated L7 to point at 93
# The dial is rotated L875 to point at 18
# The dial is rotated L807 to point at 11
# The dial is rotated L57 to point at 54
# The dial is rotated R46 to point at 0
# The dial is rotated R55 to point at 55
# The dial is rotated R45 to point at 0
# The dial is rotated L89 to point at 11
# The dial is rotated L4 to point at 7
# The dial is rotated R11 to point at 18
# The dial is rotated R26 to point at 44
# The dial is rotated L613 to point at 31
# The dial is rotated R469 to point at 0
# The dial is rotated L60 to point at 40
# The dial is rotated R84 to point at 24
# The dial is rotated R69 to point at 93
# The dial is rotated R7 to point at 0
# The dial is rotated R159 to point at 59
# The dial is rotated R24 to point at 83
# The dial is rotated L47 to point at 36
# The dial is rotated R51 to point at 87
# The dial is rotated R13 to point at 0
# The dial is rotated L878 to point at 22
# The dial is rotated L22 to point at 0
# The dial is rotated L220 to point at 80
# The dial is rotated L29 to point at 51
# The dial is rotated R48 to point at 99
# The dial is rotated R29 to point at 28
# The dial is rotated L37 to point at 91
# The dial is rotated R75 to point at 66
# The dial is rotated R42 to point at 8
# The dial is rotated R87 to point at 95
# The dial is rotated L95 to point at 0
# The dial is rotated R21 to point at 21
# The dial is rotated R179 to point at 0
# The dial is rotated L188 to point at 12
# The dial is rotated L54 to point at 58
# The dial is rotated R42 to point at 0
# The dial is rotated L56 to point at 44
# The dial is rotated L46 to point at 98
# The dial is rotated L39 to point at 59
# The dial is rotated L493 to point at 66
# The dial is rotated L74 to point at 92
# The dial is rotated R9 to point at 1
# The dial is rotated L81 to point at 20
# The dial is rotated R24 to point at 44
# The dial is rotated L28 to point at 16
# The dial is rotated L57 to point at 59
# The dial is rotated L46 to point at 13
# The dial is rotated L13 to point at 0
# The dial is rotated R11 to point at 11
# The dial is rotated L22 to point at 89
# The dial is rotated L96 to point at 93
# The dial is rotated R7 to point at 0
# The dial is rotated L94 to point at 6
# The dial is rotated L82 to point at 24
# The dial is rotated R99 to point at 23
# The dial is rotated R12 to point at 35
# The dial is rotated R65 to point at 0
# The dial is rotated L83 to point at 17
# The dial is rotated L17 to point at 0
# The dial is rotated L47 to point at 53
# The dial is rotated L53 to point at 0
# The dial is rotated L263 to point at 37
# The dial is rotated L46 to point at 91
# The dial is rotated L5 to point at 86
# The dial is rotated R714 to point at 0
# The dial is rotated R990 to point at 90
# The dial is rotated R14 to point at 4
# The dial is rotated L53 to point at 51
# The dial is rotated L36 to point at 15
# The dial is rotated R85 to point at 0
# The dial is rotated L3 to point at 97
# The dial is rotated L97 to point at 0
# The dial is rotated L66 to point at 34
# The dial is rotated R766 to point at 0
# The dial is rotated L61 to point at 39
# The dial is rotated R661 to point at 0
# The dial is rotated L25 to point at 75
# The dial is rotated L5 to point at 70
# The dial is rotated R65 to point at 35
# The dial is rotated L75 to point at 60
# The dial is rotated L560 to point at 0
# The dial is rotated R72 to point at 72
# The dial is rotated R556 to point at 28
# The dial is rotated R9 to point at 37
# The dial is rotated L7 to point at 30
# The dial is rotated R170 to point at 0
# The dial is rotated R20 to point at 20
# The dial is rotated R40 to point at 60
# The dial is rotated L860 to point at 0
# The dial is rotated L21 to point at 79
# The dial is rotated R50 to point at 29
# The dial is rotated R524 to point at 53
# The dial is rotated R47 to point at 0
# The dial is rotated L304 to point at 96
# The dial is rotated R12 to point at 8
# The dial is rotated R41 to point at 49
# The dial is rotated L55 to point at 94
# The dial is rotated L5 to point at 89
# The dial is rotated L48 to point at 41
# The dial is rotated R428 to point at 69
# The dial is rotated R313 to point at 82
# The dial is rotated R68 to point at 50
# The dial is rotated R410 to point at 60
# The dial is rotated R2 to point at 62
# The dial is rotated L687 to point at 75
# The dial is rotated R25 to point at 0
# The dial is rotated R37 to point at 37
# The dial is rotated R22 to point at 59
# The dial is rotated R12 to point at 71
# The dial is rotated L9 to point at 62
# The dial is rotated R38 to point at 0
# The dial is rotated R54 to point at 54
# The dial is rotated R243 to point at 97
# The dial is rotated L89 to point at 8
# The dial is rotated L8 to point at 0
# The dial is rotated R29 to point at 29
# The dial is rotated L66 to point at 63
# The dial is rotated L63 to point at 0
# The dial is rotated L815 to point at 85
# The dial is rotated R115 to point at 0
# The dial is rotated L69 to point at 31
# The dial is rotated R71 to point at 2
# The dial is rotated R98 to point at 0
# The dial is rotated R70 to point at 70
# The dial is rotated R31 to point at 1
# The dial is rotated L22 to point at 79
# The dial is rotated R21 to point at 0
# The dial is rotated R47 to point at 47
# The dial is rotated R16 to point at 63
# The dial is rotated R37 to point at 0
# The dial is rotated L80 to point at 20
# The dial is rotated L65 to point at 55
# The dial is rotated R45 to point at 0
# The dial is rotated R55 to point at 55
# The dial is rotated L355 to point at 0
# The dial is rotated L23 to point at 77
# The dial is rotated L48 to point at 29
# The dial is rotated R93 to point at 22
# The dial is rotated R78 to point at 0
# The dial is rotated L23 to point at 77
# The dial is rotated L44 to point at 33
# The dial is rotated R24 to point at 57
# The dial is rotated L38 to point at 19
# The dial is rotated L7 to point at 12
# The dial is rotated L12 to point at 0
# The dial is rotated R73 to point at 73
# The dial is rotated L67 to point at 6
# The dial is rotated R94 to point at 0
# The dial is rotated L13 to point at 87
# The dial is rotated L87 to point at 0
# The dial is rotated R31 to point at 31
# The dial is rotated L59 to point at 72
# The dial is rotated R54 to point at 26
# The dial is rotated R180 to point at 6
# The dial is rotated L404 to point at 2
# The dial is rotated L776 to point at 26
# The dial is rotated R36 to point at 62
# The dial is rotated L590 to point at 72
# The dial is rotated R28 to point at 0
# The dial is rotated L77 to point at 23
# The dial is rotated L914 to point at 9
# The dial is rotated R54 to point at 63
# The dial is rotated L963 to point at 0
# The dial is rotated R70 to point at 70
# The dial is rotated R13 to point at 83
# The dial is rotated R517 to point at 0
# The dial is rotated L46 to point at 54
# The dial is rotated R46 to point at 0
# The dial is rotated L13 to point at 87
# The dial is rotated L28 to point at 59
# The dial is rotated R38 to point at 97
# The dial is rotated R39 to point at 36
# The dial is rotated L36 to point at 0
# The dial is rotated R33 to point at 33
# The dial is rotated L33 to point at 0
# The dial is rotated R689 to point at 89
# The dial is rotated R85 to point at 74
# The dial is rotated R56 to point at 30
# The dial is rotated R615 to point at 45
# The dial is rotated L45 to point at 0
# The dial is rotated L51 to point at 49
# The dial is rotated R812 to point at 61
# The dial is rotated R39 to point at 0
# The dial is rotated R83 to point at 83
# The dial is rotated L686 to point at 97
# The dial is rotated L49 to point at 48
# The dial is rotated L48 to point at 0
# The dial is rotated L82 to point at 18
# The dial is rotated L52 to point at 66
# The dial is rotated R34 to point at 0
# The dial is rotated R52 to point at 52
# The dial is rotated R88 to point at 40
# The dial is rotated L71 to point at 69
# The dial is rotated L69 to point at 0
# The dial is rotated R46 to point at 46
# The dial is rotated R54 to point at 0
# The dial is rotated L17 to point at 83
# The dial is rotated R17 to point at 0
# The dial is rotated R70 to point at 70
# The dial is rotated L70 to point at 0
# The dial is rotated L641 to point at 59
# The dial is rotated L362 to point at 97
# The dial is rotated R17 to point at 14
# The dial is rotated L6 to point at 8
# The dial is rotated L8 to point at 0
# The dial is rotated R4 to point at 4
# The dial is rotated R96 to point at 0
# The dial is rotated R514 to point at 14
# The dial is rotated L20 to point at 94
# The dial is rotated L75 to point at 19
# The dial is rotated R37 to point at 56
# The dial is rotated R37 to point at 93
# The dial is rotated R7 to point at 0
# The dial is rotated L74 to point at 26
# The dial is rotated R56 to point at 82
# The dial is rotated L51 to point at 31
# The dial is rotated L31 to point at 0
# The dial is rotated R42 to point at 42
# The dial is rotated R94 to point at 36
# The dial is rotated L25 to point at 11
# The dial is rotated L11 to point at 0
# The dial is rotated L31 to point at 69
# The dial is rotated L8 to point at 61
# The dial is rotated L761 to point at 0
# The dial is rotated R26 to point at 26
# The dial is rotated R74 to point at 0
# The dial is rotated L102 to point at 98
# The dial is rotated R2 to point at 0
# The dial is rotated L67 to point at 33
# The dial is rotated R3 to point at 36
# The dial is rotated R94 to point at 30
# The dial is rotated R95 to point at 25
# The dial is rotated L47 to point at 78
# The dial is rotated L19 to point at 59
# The dial is rotated L19 to point at 40
# The dial is rotated L40 to point at 0
# The dial is rotated R177 to point at 77
# The dial is rotated L37 to point at 40
# The dial is rotated L40 to point at 0
# The dial is rotated L46 to point at 54
# The dial is rotated R20 to point at 74
# The dial is rotated R126 to point at 0
# The dial is rotated R89 to point at 89
# The dial is rotated R40 to point at 29
# The dial is rotated R17 to point at 46
# The dial is rotated R876 to point at 22
# The dial is rotated R251 to point at 73
# The dial is rotated L37 to point at 36
# The dial is rotated R758 to point at 94
# The dial is rotated R6 to point at 0
# The dial is rotated R96 to point at 96
# The dial is rotated L20 to point at 76
# The dial is rotated R24 to point at 0
# The dial is rotated R472 to point at 72
# The dial is rotated R28 to point at 0
# The dial is rotated L83 to point at 17
# The dial is rotated L17 to point at 0
# The dial is rotated R588 to point at 88
# The dial is rotated L244 to point at 44
# The dial is rotated R312 to point at 56
# The dial is rotated R15 to point at 71
# The dial is rotated R13 to point at 84
# The dial is rotated L284 to point at 0
# The dial is rotated L36 to point at 64
# The dial is rotated L20 to point at 44
# The dial is rotated L820 to point at 24
# The dial is rotated L14 to point at 10
# The dial is rotated R74 to point at 84
# The dial is rotated L84 to point at 0
# The dial is rotated L49 to point at 51
# The dial is rotated R49 to point at 0
# The dial is rotated L92 to point at 8
# The dial is rotated R86 to point at 94
# The dial is rotated R59 to point at 53
# The dial is rotated R181 to point at 34
# The dial is rotated R66 to point at 0
# The dial is rotated L74 to point at 26
# The dial is rotated R637 to point at 63
# The dial is rotated R52 to point at 15
# The dial is rotated L15 to point at 0
# The dial is rotated L21 to point at 79
# The dial is rotated R21 to point at 0
# The dial is rotated R83 to point at 83
# The dial is rotated R12 to point at 95
# The dial is rotated R5 to point at 0
# The dial is rotated L83 to point at 17
# The dial is rotated R201 to point at 18
# The dial is rotated R31 to point at 49
# The dial is rotated L63 to point at 86
# The dial is rotated L45 to point at 41
# The dial is rotated R97 to point at 38
# The dial is rotated R22 to point at 60
# The dial is rotated R34 to point at 94
# The dial is rotated R14 to point at 8
# The dial is rotated L542 to point at 66
# The dial is rotated L29 to point at 37
# The dial is rotated R63 to point at 0
# The dial is rotated L521 to point at 79
# The dial is rotated R12 to point at 91
# The dial is rotated L32 to point at 59
# The dial is rotated L956 to point at 3
# The dial is rotated L21 to point at 82
# The dial is rotated R71 to point at 53
# The dial is rotated R47 to point at 0
# The dial is rotated R119 to point at 19
# The dial is rotated R81 to point at 0
# The dial is rotated R56 to point at 56
# The dial is rotated L56 to point at 0
# The dial is rotated R610 to point at 10
# The dial is rotated R90 to point at 0
# The dial is rotated R12 to point at 12
# The dial is rotated R408 to point at 20
# The dial is rotated R580 to point at 0
# The dial is rotated L68 to point at 32
# The dial is rotated R99 to point at 31
# The dial is rotated L58 to point at 73
# The dial is rotated R23 to point at 96
# The dial is rotated R604 to point at 0
# The dial is rotated R72 to point at 72
# The dial is rotated L30 to point at 42
# The dial is rotated L89 to point at 53
# The dial is rotated R893 to point at 46
# The dial is rotated L54 to point at 92
# The dial is rotated L92 to point at 0
# The dial is rotated R51 to point at 51
# The dial is rotated L7 to point at 44
# The dial is rotated R77 to point at 21
# The dial is rotated L21 to point at 0
# The dial is rotated L66 to point at 34
# The dial is rotated L55 to point at 79
# The dial is rotated L96 to point at 83
# The dial is rotated R17 to point at 0
# The dial is rotated R4 to point at 4
# The dial is rotated L842 to point at 62
# The dial is rotated L62 to point at 0
# The dial is rotated R53 to point at 53
# The dial is rotated R347 to point at 0
# The dial is rotated L250 to point at 50
# The dial is rotated R50 to point at 0
# The dial is rotated R34 to point at 34
# The dial is rotated R666 to point at 0
# The dial is rotated R4 to point at 4
# The dial is rotated L37 to point at 67
# The dial is rotated L724 to point at 43
# The dial is rotated L43 to point at 0
# The dial is rotated R10 to point at 10
# The dial is rotated L110 to point at 0
# The dial is rotated R1 to point at 1
# The dial is rotated L1 to point at 0
# The dial is rotated R331 to point at 31
# The dial is rotated R435 to point at 66
# The dial is rotated R38 to point at 4
# The dial is rotated L739 to point at 65
# The dial is rotated R82 to point at 47
# The dial is rotated R78 to point at 25
# The dial is rotated R75 to point at 0
# The dial is rotated R1 to point at 1
# The dial is rotated R99 to point at 0
# The dial is rotated L29 to point at 71
# The dial is rotated L28 to point at 43
# The dial is rotated L906 to point at 37
# The dial is rotated R53 to point at 90
# The dial is rotated R30 to point at 20
# The dial is rotated R93 to point at 13
# The dial is rotated L19 to point at 94
# The dial is rotated L27 to point at 67
# The dial is rotated L67 to point at 0
# The dial is rotated R49 to point at 49
# The dial is rotated L76 to point at 73
# The dial is rotated R15 to point at 88
# The dial is rotated L56 to point at 32
# The dial is rotated L76 to point at 56
# The dial is rotated R11 to point at 67
# The dial is rotated L70 to point at 97
# The dial is rotated R213 to point at 10
# The dial is rotated L10 to point at 0
# The dial is rotated R97 to point at 97
# The dial is rotated L438 to point at 59
# The dial is rotated R55 to point at 14
# The dial is rotated L22 to point at 92
# The dial is rotated R8 to point at 0
# The dial is rotated L42 to point at 58
# The dial is rotated R12 to point at 70
# The dial is rotated L270 to point at 0
# The dial is rotated R82 to point at 82
# The dial is rotated L279 to point at 3
# The dial is rotated L694 to point at 9
# The dial is rotated R70 to point at 79
# The dial is rotated R41 to point at 20
# The dial is rotated R74 to point at 94
# The dial is rotated L41 to point at 53
# The dial is rotated R71 to point at 24
# The dial is rotated L96 to point at 28
# The dial is rotated L294 to point at 34
# The dial is rotated R59 to point at 93
# The dial is rotated L693 to point at 0
# The dial is rotated L17 to point at 83
# The dial is rotated R815 to point at 98
# The dial is rotated L99 to point at 99
# The dial is rotated R19 to point at 18
# The dial is rotated R82 to point at 0
# The dial is rotated L81 to point at 19
# The dial is rotated R32 to point at 51
# The dial is rotated L78 to point at 73
# The dial is rotated R27 to point at 0
# The dial is rotated L36 to point at 64
# The dial is rotated R17 to point at 81
# The dial is rotated R97 to point at 78
# The dial is rotated R32 to point at 10
# The dial is rotated R90 to point at 0
# The dial is rotated L85 to point at 15
# The dial is rotated L15 to point at 0
# The dial is rotated L24 to point at 76
# The dial is rotated L76 to point at 0
# The dial is rotated L489 to point at 11
# The dial is rotated R34 to point at 45
# The dial is rotated R355 to point at 0
# The dial is rotated L99 to point at 1
# The dial is rotated L943 to point at 58
# The dial is rotated L180 to point at 78
# The dial is rotated R22 to point at 0
# The dial is rotated R38 to point at 38
# The dial is rotated R62 to point at 0
# The dial is rotated R39 to point at 39
# The dial is rotated L239 to point at 0
# The dial is rotated L54 to point at 46
# The dial is rotated L67 to point at 79
# The dial is rotated L65 to point at 14
# The dial is rotated R81 to point at 95
# The dial is rotated L21 to point at 74
# The dial is rotated R254 to point at 28
# The dial is rotated R30 to point at 58
# The dial is rotated R39 to point at 97
# The dial is rotated R992 to point at 89
# The dial is rotated L54 to point at 35
# The dial is rotated L182 to point at 53
# The dial is rotated L453 to point at 0
# The dial is rotated L31 to point at 69
# The dial is rotated R31 to point at 0
# The dial is rotated L18 to point at 82
# The dial is rotated L2 to point at 80
# The dial is rotated L539 to point at 41
# The dial is rotated R4 to point at 45
# The dial is rotated R71 to point at 16
# The dial is rotated L968 to point at 48
# The dial is rotated R52 to point at 0
# The dial is rotated R68 to point at 68
# The dial is rotated R32 to point at 0
# The dial is rotated R10 to point at 10
# The dial is rotated R665 to point at 75
# The dial is rotated R86 to point at 61
# The dial is rotated R31 to point at 92
# The dial is rotated L83 to point at 9
# The dial is rotated L82 to point at 27
# The dial is rotated R73 to point at 0
# The dial is rotated L81 to point at 19
# The dial is rotated L19 to point at 0
# The dial is rotated R714 to point at 14
# The dial is rotated R86 to point at 0
# The dial is rotated R96 to point at 96
# The dial is rotated R4 to point at 0
# The dial is rotated R653 to point at 53
# The dial is rotated L52 to point at 1
# The dial is rotated R920 to point at 21
# The dial is rotated R379 to point at 0
# The dial is rotated R47 to point at 47
# The dial is rotated L8 to point at 39
# The dial is rotated L36 to point at 3
# The dial is rotated R46 to point at 49
# The dial is rotated L49 to point at 0
# The dial is rotated R32 to point at 32
# The dial is rotated L932 to point at 0
# The dial is rotated R50 to point at 50
# The dial is rotated L950 to point at 0
# The dial is rotated L67 to point at 33
# The dial is rotated R405 to point at 38
# The dial is rotated L538 to point at 0
# The dial is rotated L76 to point at 24
# The dial is rotated L24 to point at 0
# The dial is rotated R93 to point at 93
# The dial is rotated R53 to point at 46
# The dial is rotated L46 to point at 0
# The dial is rotated R43 to point at 43
# The dial is rotated L543 to point at 0
# The dial is rotated R93 to point at 93
# The dial is rotated R2 to point at 95
# The dial is rotated R6 to point at 1
# The dial is rotated R412 to point at 13
# The dial is rotated L93 to point at 20
# The dial is rotated L85 to point at 35
# The dial is rotated R61 to point at 96
# The dial is rotated L57 to point at 39
# The dial is rotated R76 to point at 15
# The dial is rotated L115 to point at 0
# The dial is rotated L67 to point at 33
# The dial is rotated L33 to point at 0
# The dial is rotated L814 to point at 86
# The dial is rotated L62 to point at 24
# The dial is rotated L24 to point at 0
# The dial is rotated R73 to point at 73
# The dial is rotated L73 to point at 0
# The dial is rotated L46 to point at 54
# The dial is rotated L14 to point at 40
# The dial is rotated R125 to point at 65
# The dial is rotated R35 to point at 0
# The dial is rotated R15 to point at 15
# The dial is rotated L31 to point at 84
# The dial is rotated L56 to point at 28
# The dial is rotated L28 to point at 0
# The dial is rotated R96 to point at 96
# The dial is rotated L98 to point at 98
# The dial is rotated R17 to point at 15
# The dial is rotated L15 to point at 0
# The dial is rotated R53 to point at 53
# The dial is rotated R27 to point at 80
# The dial is rotated L80 to point at 0
# The dial is rotated L31 to point at 69
# The dial is rotated R16 to point at 85
# The dial is rotated L74 to point at 11
# The dial is rotated L111 to point at 0
# The dial is rotated L662 to point at 38
# The dial is rotated R353 to point at 91
# The dial is rotated R52 to point at 43
# The dial is rotated R92 to point at 35
# The dial is rotated L172 to point at 63
# The dial is rotated L74 to point at 89
# The dial is rotated R11 to point at 0
# The dial is rotated L8 to point at 92
# The dial is rotated L92 to point at 0
# The dial is rotated L4 to point at 96
# The dial is rotated R46 to point at 42
# The dial is rotated R41 to point at 83
# The dial is rotated L283 to point at 0
# The dial is rotated R63 to point at 63
# The dial is rotated R26 to point at 89
# The dial is rotated L31 to point at 58
# The dial is rotated L958 to point at 0
# The dial is rotated R28 to point at 28
# The dial is rotated R72 to point at 0
# The dial is rotated L55 to point at 45
# The dial is rotated R43 to point at 88
# The dial is rotated R9 to point at 97
# The dial is rotated L97 to point at 0
# The dial is rotated L8 to point at 92
# The dial is rotated R8 to point at 0
# The dial is rotated R877 to point at 77
# The dial is rotated L44 to point at 33
# The dial is rotated R23 to point at 56
# The dial is rotated L56 to point at 0
# The dial is rotated R75 to point at 75
# The dial is rotated L75 to point at 0
# The dial is rotated L777 to point at 23
# The dial is rotated R1 to point at 24
# The dial is rotated L24 to point at 0
# The dial is rotated L83 to point at 17
# The dial is rotated L17 to point at 0
# The dial is rotated R43 to point at 43
# The dial is rotated R24 to point at 67
# The dial is rotated R1 to point at 68
# The dial is rotated L42 to point at 26
# The dial is rotated L84 to point at 42
# The dial is rotated R758 to point at 0
# The dial is rotated L18 to point at 82
# The dial is rotated R63 to point at 45
# The dial is rotated R32 to point at 77
# The dial is rotated R71 to point at 48
# The dial is rotated L741 to point at 7
# The dial is rotated R85 to point at 92
# The dial is rotated R56 to point at 48
# The dial is rotated R55 to point at 3
# The dial is rotated L11 to point at 92
# The dial is rotated L50 to point at 42
# The dial is rotated L85 to point at 57
# The dial is rotated R56 to point at 13
# The dial is rotated R8 to point at 21
# The dial is rotated R46 to point at 67
# The dial is rotated L353 to point at 14
# The dial is rotated L99 to point at 15
# The dial is rotated L615 to point at 0
# The dial is rotated L612 to point at 88
# The dial is rotated L28 to point at 60
# The dial is rotated L531 to point at 29
# The dial is rotated L29 to point at 0
# The dial is rotated R88 to point at 88
# The dial is rotated L88 to point at 0
# The dial is rotated R34 to point at 34
# The dial is rotated L69 to point at 65
# The dial is rotated R423 to point at 88
# The dial is rotated L84 to point at 4
# The dial is rotated L34 to point at 70
# The dial is rotated R30 to point at 0
# The dial is rotated L42 to point at 58
# The dial is rotated R51 to point at 9
# The dial is rotated L81 to point at 28
# The dial is rotated R61 to point at 89
# The dial is rotated R233 to point at 22
# The dial is rotated R52 to point at 74
# The dial is rotated L374 to point at 0
# The dial is rotated R85 to point at 85
# The dial is rotated L20 to point at 65
# The dial is rotated L32 to point at 33
# The dial is rotated L4 to point at 29
# The dial is rotated R83 to point at 12
# The dial is rotated L471 to point at 41
# The dial is rotated R46 to point at 87
# The dial is rotated L6 to point at 81
# The dial is rotated R87 to point at 68
# The dial is rotated R32 to point at 0
# The dial is rotated R55 to point at 55
# The dial is rotated L618 to point at 37
# The dial is rotated L39 to point at 98
# The dial is rotated L98 to point at 0
# The dial is rotated L29 to point at 71
# The dial is rotated L41 to point at 30
# The dial is rotated R25 to point at 55
# The dial is rotated L19 to point at 36
# The dial is rotated L936 to point at 0
# The dial is rotated L39 to point at 61
# The dial is rotated L61 to point at 0
# The dial is rotated L61 to point at 39
# The dial is rotated L36 to point at 3
# The dial is rotated L303 to point at 0
# The dial is rotated R44 to point at 44
# The dial is rotated L2 to point at 42
# The dial is rotated L97 to point at 45
# The dial is rotated R41 to point at 86
# The dial is rotated R35 to point at 21
# The dial is rotated L21 to point at 0
# The dial is rotated L72 to point at 28
# The dial is rotated R72 to point at 0
# The dial is rotated L85 to point at 15
# The dial is rotated L266 to point at 49
# The dial is rotated R33 to point at 82
# The dial is rotated R18 to point at 0
# The dial is rotated L260 to point at 40
# The dial is rotated R91 to point at 31
# The dial is rotated L9 to point at 22
# The dial is rotated R58 to point at 80
# The dial is rotated R825 to point at 5
# The dial is rotated L705 to point at 0
# The dial is rotated R92 to point at 92
# The dial is rotated R29 to point at 21
# The dial is rotated R20 to point at 41
# The dial is rotated R59 to point at 0
# The dial is rotated R69 to point at 69
# The dial is rotated L61 to point at 8
# The dial is rotated R28 to point at 36
# The dial is rotated R86 to point at 22
# The dial is rotated R10 to point at 32
# The dial is rotated R507 to point at 39
# The dial is rotated R61 to point at 0
# The dial is rotated L4 to point at 96
# The dial is rotated R504 to point at 0
# The dial is rotated L227 to point at 73
# The dial is rotated L22 to point at 51
# The dial is rotated R49 to point at 0
# The dial is rotated R54 to point at 54
# The dial is rotated L20 to point at 34
# The dial is rotated L2 to point at 32
# The dial is rotated R467 to point at 99
# The dial is rotated L83 to point at 16
# The dial is rotated L16 to point at 0
# The dial is rotated L7 to point at 93
# The dial is rotated L93 to point at 0
# The dial is rotated R99 to point at 99
# The dial is rotated R61 to point at 60
# The dial is rotated R23 to point at 83
# The dial is rotated L85 to point at 98
# The dial is rotated R19 to point at 17
# The dial is rotated L95 to point at 22
# The dial is rotated L94 to point at 28
# The dial is rotated L28 to point at 0
# The dial is rotated R273 to point at 73
# The dial is rotated R53 to point at 26
# The dial is rotated R74 to point at 0
# The dial is rotated R69 to point at 69
# The dial is rotated L605 to point at 64
# The dial is rotated L180 to point at 84
# The dial is rotated R17 to point at 1
# The dial is rotated R4 to point at 5
# The dial is rotated R13 to point at 18
# The dial is rotated L36 to point at 82
# The dial is rotated L82 to point at 0
# The dial is rotated L66 to point at 34
# The dial is rotated L1 to point at 33
# The dial is rotated R67 to point at 0
# The dial is rotated R97 to point at 97
# The dial is rotated R34 to point at 31
# The dial is rotated L7 to point at 24
# The dial is rotated R276 to point at 0
# The dial is rotated L328 to point at 72
# The dial is rotated L72 to point at 0
# The dial is rotated L44 to point at 56
# The dial is rotated R87 to point at 43
# The dial is rotated R69 to point at 12
# The dial is rotated L12 to point at 0
# The dial is rotated L46 to point at 54
# The dial is rotated L60 to point at 94
# The dial is rotated R7 to point at 1
# The dial is rotated L72 to point at 29
# The dial is rotated R69 to point at 98
# The dial is rotated L60 to point at 38
# The dial is rotated R83 to point at 21
# The dial is rotated R360 to point at 81
# The dial is rotated L54 to point at 27
# The dial is rotated R76 to point at 3
# The dial is rotated L3 to point at 0
# The dial is rotated R54 to point at 54
# The dial is rotated R46 to point at 0
# The dial is rotated R6 to point at 6
# The dial is rotated L74 to point at 32
# The dial is rotated L32 to point at 0
# The dial is rotated R211 to point at 11
# The dial is rotated R89 to point at 0
# The dial is rotated R63 to point at 63
# The dial is rotated L63 to point at 0
# The dial is rotated L59 to point at 41
# The dial is rotated L39 to point at 2
# The dial is rotated L5 to point at 97
# The dial is rotated R3 to point at 0
# The dial is rotated R19 to point at 19
# The dial is rotated L64 to point at 55
# The dial is rotated L90 to point at 65
# The dial is rotated L3 to point at 62
# The dial is rotated L25 to point at 37
# The dial is rotated L37 to point at 0
# The dial is rotated R52 to point at 52
# The dial is rotated R48 to point at 0
# The dial is rotated R299 to point at 99
# The dial is rotated L85 to point at 14
# The dial is rotated L14 to point at 0
# The dial is rotated R17 to point at 17
# The dial is rotated L17 to point at 0
# The dial is rotated L4 to point at 96
# The dial is rotated L57 to point at 39
# The dial is rotated L90 to point at 49
# The dial is rotated L61 to point at 88
# The dial is rotated L86 to point at 2
# The dial is rotated R98 to point at 0
# The dial is rotated L79 to point at 21
# The dial is rotated R10 to point at 31
# The dial is rotated L331 to point at 0
# The dial is rotated L322 to point at 78
# The dial is rotated R733 to point at 11
# The dial is rotated L611 to point at 0
# The dial is rotated R28 to point at 28
# The dial is rotated R298 to point at 26
# The dial is rotated R74 to point at 0
# The dial is rotated L92 to point at 8
# The dial is rotated L96 to point at 12
# The dial is rotated L48 to point at 64
# The dial is rotated R40 to point at 4
# The dial is rotated R76 to point at 80
# The dial is rotated L80 to point at 0
# The dial is rotated R39 to point at 39
# The dial is rotated L24 to point at 15
# The dial is rotated R96 to point at 11
# The dial is rotated L11 to point at 0
# The dial is rotated R7 to point at 7
# The dial is rotated R93 to point at 0
# The dial is rotated R860 to point at 60
# The dial is rotated L78 to point at 82
# The dial is rotated L444 to point at 38
# The dial is rotated R62 to point at 0
# The dial is rotated L661 to point at 39
# The dial is rotated R85 to point at 24
# The dial is rotated L63 to point at 61
# The dial is rotated R62 to point at 23
# The dial is rotated R77 to point at 0
# The dial is rotated L89 to point at 11
# The dial is rotated R19 to point at 30
# The dial is rotated L30 to point at 0
# The dial is rotated L678 to point at 22
# The dial is rotated L22 to point at 0
# The dial is rotated R69 to point at 69
# The dial is rotated L64 to point at 5
# The dial is rotated L5 to point at 0
# The dial is rotated L46 to point at 54
# The dial is rotated L78 to point at 76
# The dial is rotated L876 to point at 0
# The dial is rotated R18 to point at 18
# The dial is rotated L18 to point at 0
# The dial is rotated L414 to point at 86
# The dial is rotated R88 to point at 74
# The dial is rotated R626 to point at 0
# The dial is rotated L70 to point at 30
# The dial is rotated R713 to point at 43
# The dial is rotated L53 to point at 90
# The dial is rotated R210 to point at 0
# The dial is rotated R94 to point at 94
# The dial is rotated L394 to point at 0
# The dial is rotated L5 to point at 95
# The dial is rotated R953 to point at 48
# The dial is rotated L48 to point at 0
# The dial is rotated L410 to point at 90
# The dial is rotated L269 to point at 21
# The dial is rotated R872 to point at 93
# The dial is rotated R70 to point at 63
# The dial is rotated R37 to point at 0
# The dial is rotated L49 to point at 51
# The dial is rotated R766 to point at 17
# The dial is rotated L11 to point at 6
# The dial is rotated R35 to point at 41
# The dial is rotated L17 to point at 24
# The dial is rotated R650 to point at 74
# The dial is rotated L474 to point at 0
# The dial is rotated R75 to point at 75
# The dial is rotated R428 to point at 3
# The dial is rotated R883 to point at 86
# The dial is rotated L86 to point at 0
# The dial is rotated L241 to point at 59
# The dial is rotated R24 to point at 83
# The dial is rotated R75 to point at 58
# The dial is rotated L68 to point at 90
# The dial is rotated L97 to point at 93
# The dial is rotated R17 to point at 10
# The dial is rotated R90 to point at 0
# The dial is rotated L84 to point at 16
# The dial is rotated L16 to point at 0
# The dial is rotated R17 to point at 17
# The dial is rotated L80 to point at 37
# The dial is rotated L37 to point at 0
# The dial is rotated R282 to point at 82
# The dial is rotated R107 to point at 89
# The dial is rotated R44 to point at 33
# The dial is rotated L26 to point at 7
# The dial is rotated R77 to point at 84
# The dial is rotated L84 to point at 0
# The dial is rotated R133 to point at 33
# The dial is rotated R67 to point at 0
# The dial is rotated R32 to point at 32
# The dial is rotated R331 to point at 63
# The dial is rotated L63 to point at 0
# The dial is rotated R86 to point at 86
# The dial is rotated R23 to point at 9
# The dial is rotated R91 to point at 0
# The dial is rotated R95 to point at 95
# The dial is rotated R39 to point at 34
# The dial is rotated R92 to point at 26
# The dial is rotated R202 to point at 28
# The dial is rotated L35 to point at 93
# The dial is rotated L62 to point at 31
# The dial is rotated R72 to point at 3
# The dial is rotated L10 to point at 93
# The dial is rotated R124 to point at 17
# The dial is rotated L33 to point at 84
# The dial is rotated R16 to point at 0
# The dial is rotated R402 to point at 2
# The dial is rotated L98 to point at 4
# The dial is rotated R96 to point at 0
# The dial is rotated L246 to point at 54
# The dial is rotated L49 to point at 5
# The dial is rotated R95 to point at 0
# The dial is rotated R12 to point at 12
# The dial is rotated L312 to point at 0
# The dial is rotated R474 to point at 74
# The dial is rotated R25 to point at 99
# The dial is rotated L99 to point at 0
# The dial is rotated L16 to point at 84
# The dial is rotated L96 to point at 88
# The dial is rotated R56 to point at 44
# The dial is rotated R98 to point at 42
# The dial is rotated L42 to point at 0
# The dial is rotated L73 to point at 27
# The dial is rotated R354 to point at 81
# The dial is rotated L23 to point at 58
# The dial is rotated R32 to point at 90
# The dial is rotated L81 to point at 9
# The dial is rotated R6 to point at 15
# ...
# The dial is rotated L3 to point at 97
# The dial is rotated R3 to point at 0
# The dial is rotated R54 to point at 54
# The dial is rotated R46 to point at 0
# The dial is rotated L19 to point at 81
# The dial is rotated L26 to point at 55
# The dial is rotated L55 to point at 0
# The dial is rotated L7 to point at 93
# The dial is rotated R218 to point at 11
# The dial is rotated L11 to point at 0
# The dial is rotated L20 to point at 80
# The dial is rotated L48 to point at 32
# The dial is rotated L82 to point at 50
# The dial is rotated L50 to point at 0
# The dial is rotated L54 to point at 46
# The dial is rotated R274 to point at 20
# The dial is rotated L6 to point at 14
# The dial is rotated L97 to point at 17
# The dial is rotated R78 to point at 95
# The dial is rotated R48 to point at 43
# The dial is rotated R813 to point at 56
# The dial is rotated L256 to point at 0
# The dial is rotated L32 to point at 68
# The dial is rotated L58 to point at 10
# The dial is rotated R41 to point at 51
# The dial is rotated R49 to point at 0
# The dial is rotated L67 to point at 33
# The dial is rotated R967 to point at 0
# The dial is rotated L88 to point at 12
# The dial is rotated L25 to point at 87
# The dial is rotated R2 to point at 89
# The dial is rotated L84 to point at 5
# The dial is rotated R95 to point at 0
# The dial is rotated R12 to point at 12
# The dial is rotated L595 to point at 17
# The dial is rotated L90 to point at 27
# The dial is rotated L27 to point at 0
# The dial is rotated L58 to point at 42
# The dial is rotated L59 to point at 83
# The dial is rotated L83 to point at 0
# The dial is rotated R51 to point at 51
# The dial is rotated L151 to point at 0
# The dial is rotated L37 to point at 63
# The dial is rotated R37 to point at 0
# The dial is rotated L85 to point at 15
# The dial is rotated L415 to point at 0
# The dial is rotated R512 to point at 12
# The dial is rotated R95 to point at 7
# The dial is rotated L43 to point at 64
# The dial is rotated L71 to point at 93
# The dial is rotated R59 to point at 52
# The dial is rotated R66 to point at 18
# The dial is rotated R53 to point at 71
# The dial is rotated R23 to point at 94
# The dial is rotated L13 to point at 81
# The dial is rotated R19 to point at 0
# The dial is rotated L56 to point at 44
# The dial is rotated L14 to point at 30
# The dial is rotated L64 to point at 66
# The dial is rotated R47 to point at 13
# The dial is rotated R87 to point at 0
# The dial is rotated L977 to point at 23
# The dial is rotated L23 to point at 0
# The dial is rotated L35 to point at 65
# The dial is rotated R8 to point at 73
# The dial is rotated R83 to point at 56
# The dial is rotated R449 to point at 5
# The dial is rotated L5 to point at 0
# The dial is rotated L52 to point at 48
# The dial is rotated R652 to point at 0
# The dial is rotated L65 to point at 35
# The dial is rotated L90 to point at 45
# The dial is rotated L28 to point at 17
# The dial is rotated R283 to point at 0
# The dial is rotated L51 to point at 49
# The dial is rotated L45 to point at 4
# The dial is rotated R896 to point at 0
# The dial is rotated R661 to point at 61
# The dial is rotated L361 to point at 0
# The dial is rotated R42 to point at 42
# The dial is rotated L82 to point at 60
# The dial is rotated R40 to point at 0
# The dial is rotated R2 to point at 2
# The dial is rotated L2 to point at 0
# The dial is rotated L36 to point at 64
# The dial is rotated L64 to point at 0
# The dial is rotated R35 to point at 35
# The dial is rotated L378 to point at 57
# The dial is rotated R43 to point at 0
# The dial is rotated L97 to point at 3
# The dial is rotated L3 to point at 0
# The dial is rotated L33 to point at 67
# The dial is rotated L67 to point at 0
# The dial is rotated R83 to point at 83
# The dial is rotated L83 to point at 0
# The dial is rotated R77 to point at 77
# The dial is rotated R36 to point at 13
# The dial is rotated L13 to point at 0
# The dial is rotated R87 to point at 87
# The dial is rotated L76 to point at 11
# The dial is rotated R6 to point at 17
# The dial is rotated L62 to point at 55
# The dial is rotated R59 to point at 14
# The dial is rotated R166 to point at 80
# The dial is rotated R372 to point at 52
# The dial is rotated L1 to point at 51
# The dial is rotated L38 to point at 13
# The dial is rotated L13 to point at 0
# The dial is rotated R43 to point at 43
# The dial is rotated R45 to point at 88
# The dial is rotated L88 to point at 0
# The dial is rotated L80 to point at 20
# The dial is rotated L29 to point at 91
# The dial is rotated L791 to point at 0
# The dial is rotated L23 to point at 77
# The dial is rotated L77 to point at 0
# The dial is rotated L137 to point at 63
# The dial is rotated R937 to point at 0
# The dial is rotated L61 to point at 39
# The dial is rotated R61 to point at 0
# The dial is rotated L6 to point at 94
# The dial is rotated R57 to point at 51
# The dial is rotated R20 to point at 71
# The dial is rotated L71 to point at 0
# The dial is rotated L33 to point at 67
# The dial is rotated L67 to point at 0
# The dial is rotated L89 to point at 11
# The dial is rotated L8 to point at 3
# The dial is rotated R97 to point at 0
# The dial is rotated L7 to point at 93
# The dial is rotated R518 to point at 11
# The dial is rotated L11 to point at 0
# The dial is rotated L35 to point at 65
# The dial is rotated L44 to point at 21
# The dial is rotated R52 to point at 73
# The dial is rotated R20 to point at 93
# The dial is rotated R107 to point at 0
# The dial is rotated R76 to point at 76
# The dial is rotated L64 to point at 12
# The dial is rotated L21 to point at 91
# The dial is rotated L91 to point at 0
# The dial is rotated L61 to point at 39
# The dial is rotated R261 to point at 0
# The dial is rotated R68 to point at 68
# The dial is rotated R32 to point at 0
# The dial is rotated R57 to point at 57
# The dial is rotated R65 to point at 22
# The dial is rotated R78 to point at 0
# The dial is rotated R78 to point at 78
# The dial is rotated L9 to point at 69
# The dial is rotated L57 to point at 12
# The dial is rotated L1 to point at 11
# The dial is rotated L11 to point at 0
# The dial is rotated R64 to point at 64
# The dial is rotated R299 to point at 63
# The dial is rotated R67 to point at 30
# The dial is rotated R71 to point at 1
# The dial is rotated L659 to point at 42
# The dial is rotated L534 to point at 8
# The dial is rotated R35 to point at 43
# The dial is rotated L743 to point at 0
# The dial is rotated R16 to point at 16
# The dial is rotated R84 to point at 0
# The dial is rotated R757 to point at 57
# The dial is rotated L39 to point at 18
# The dial is rotated L18 to point at 0
# The dial is rotated R55 to point at 55
# The dial is rotated L93 to point at 62
# The dial is rotated R60 to point at 22
# The dial is rotated L69 to point at 53
# The dial is rotated R47 to point at 0
# The dial is rotated R10 to point at 10
# The dial is rotated L10 to point at 0
# The dial is rotated R69 to point at 69
# The dial is rotated R431 to point at 0
# The dial is rotated R25 to point at 25
# The dial is rotated R413 to point at 38
# The dial is rotated R62 to point at 0
# The dial is rotated L35 to point at 65
# The dial is rotated R544 to point at 9
# The dial is rotated R91 to point at 0
# The dial is rotated L2 to point at 98
# The dial is rotated L77 to point at 21
# The dial is rotated L721 to point at 0
# The dial is rotated L55 to point at 45
# The dial is rotated L945 to point at 0
# The dial is rotated L94 to point at 6
# The dial is rotated R327 to point at 33
# The dial is rotated R814 to point at 47
# The dial is rotated R55 to point at 2
# The dial is rotated L79 to point at 23
# The dial is rotated R768 to point at 91
# The dial is rotated L91 to point at 0
# The dial is rotated L92 to point at 8
# The dial is rotated L11 to point at 97
# The dial is rotated L26 to point at 71
# The dial is rotated R29 to point at 0
# The dial is rotated L98 to point at 2
# The dial is rotated R254 to point at 56
# The dial is rotated R24 to point at 80
# The dial is rotated L45 to point at 35
# The dial is rotated R65 to point at 0
# The dial is rotated R10 to point at 10
# The dial is rotated L13 to point at 97
# The dial is rotated R203 to point at 0
# The dial is rotated L31 to point at 69
# The dial is rotated R31 to point at 0
# The dial is rotated L48 to point at 52
# The dial is rotated L36 to point at 16
# The dial is rotated R84 to point at 0
# The dial is rotated R29 to point at 29
# The dial is rotated L29 to point at 0
# The dial is rotated L97 to point at 3
# The dial is rotated R85 to point at 88
# The dial is rotated R70 to point at 58
# The dial is rotated R30 to point at 88
# The dial is rotated R12 to point at 0
# The dial is rotated L87 to point at 13
# The dial is rotated R224 to point at 37
# The dial is rotated R63 to point at 0
# The dial is rotated L35 to point at 65
# The dial is rotated L65 to point at 0
# The dial is rotated R76 to point at 76
# The dial is rotated L176 to point at 0
# The dial is rotated L40 to point at 60
# The dial is rotated L60 to point at 0
# The dial is rotated R30 to point at 30
# The dial is rotated L39 to point at 91
# The dial is rotated L91 to point at 0
# The dial is rotated L23 to point at 77
# The dial is rotated R23 to point at 0
# The dial is rotated L82 to point at 18
# The dial is rotated R782 to point at 0
# The dial is rotated R977 to point at 77
# The dial is rotated L40 to point at 37
# The dial is rotated R44 to point at 81
# The dial is rotated L60 to point at 21
# The dial is rotated R49 to point at 70
# The dial is rotated L486 to point at 84
# The dial is rotated L36 to point at 48
# The dial is rotated L778 to point at 70
# The dial is rotated L70 to point at 0
# The dial is rotated R45 to point at 45
# The dial is rotated R93 to point at 38
# The dial is rotated L38 to point at 0
# The dial is rotated L99 to point at 1
# The dial is rotated L66 to point at 35
# The dial is rotated R28 to point at 63
# The dial is rotated L34 to point at 29
# The dial is rotated R71 to point at 0
# The dial is rotated L419 to point at 81
# The dial is rotated R81 to point at 62
# The dial is rotated R38 to point at 0
# The dial is rotated L37 to point at 63
# The dial is rotated R80 to point at 43
# The dial is rotated L43 to point at 0
# The dial is rotated R75 to point at 75
# The dial is rotated L13 to point at 62
# The dial is rotated R38 to point at 0
# The dial is rotated L19 to point at 81
# The dial is rotated R102 to point at 83
# The dial is rotated L83 to point at 0
# The dial is rotated L58 to point at 42
# The dial is rotated L10 to point at 32
# The dial is rotated R257 to point at 89
# The dial is rotated R711 to point at 0
# The dial is rotated L44 to point at 56
# The dial is rotated L22 to point at 34
# The dial is rotated L34 to point at 0
# The dial is rotated R52 to point at 52
# The dial is rotated L59 to point at 93
# The dial is rotated R815 to point at 8
# The dial is rotated R592 to point at 0
# The dial is rotated L297 to point at 3
# The dial is rotated R97 to point at 0
# The dial is rotated L66 to point at 34
# The dial is rotated R30 to point at 64
# The dial is rotated R99 to point at 63
# The dial is rotated L835 to point at 28
# The dial is rotated L73 to point at 55
# The dial is rotated L55 to point at 0
# The dial is rotated R982 to point at 82
# The dial is rotated L44 to point at 38
# The dial is rotated R62 to point at 0
# The dial is rotated R56 to point at 56
# The dial is rotated L6 to point at 50
# The dial is rotated R916 to point at 66
# The dial is rotated L64 to point at 2
# The dial is rotated R14 to point at 16
# The dial is rotated R899 to point at 15
# The dial is rotated L42 to point at 73
# The dial is rotated L73 to point at 0
# The dial is rotated R258 to point at 58
# The dial is rotated R42 to point at 0
# The dial is rotated R320 to point at 20
# The dial is rotated L184 to point at 36
# The dial is rotated L3 to point at 33
# The dial is rotated L76 to point at 57
# The dial is rotated L98 to point at 59
# The dial is rotated R41 to point at 0
# The dial is rotated R42 to point at 42
# The dial is rotated L42 to point at 0
# The dial is rotated R25 to point at 25
# The dial is rotated R22 to point at 47
# The dial is rotated R53 to point at 0
# The dial is rotated R25 to point at 25
# The dial is rotated L25 to point at 0
# The dial is rotated R79 to point at 79
# The dial is rotated L361 to point at 18
# The dial is rotated L18 to point at 0
# The dial is rotated R40 to point at 40
# The dial is rotated L40 to point at 0
# The dial is rotated R70 to point at 70
# The dial is rotated L70 to point at 0
# The dial is rotated L3 to point at 97
# The dial is rotated R65 to point at 62
# The dial is rotated R17 to point at 79
# The dial is rotated L88 to point at 91
# The dial is rotated L76 to point at 15
# The dial is rotated R85 to point at 0
# The dial is rotated R21 to point at 21
# The dial is rotated L21 to point at 0
# The dial is rotated R17 to point at 17
# The dial is rotated R96 to point at 13
# The dial is rotated R24 to point at 37
# The dial is rotated R63 to point at 0
# The dial is rotated R15 to point at 15
# The dial is rotated L15 to point at 0
# The dial is rotated R90 to point at 90
# The dial is rotated L90 to point at 0
# The dial is rotated R98 to point at 98
# The dial is rotated L3 to point at 95
# The dial is rotated R87 to point at 82
# The dial is rotated R37 to point at 19
# The dial is rotated L70 to point at 49
# The dial is rotated L49 to point at 0
# The dial is rotated L94 to point at 6
# The dial is rotated R94 to point at 0
# The dial is rotated R93 to point at 93
# The dial is rotated L93 to point at 0
# The dial is rotated R81 to point at 81
# The dial is rotated L81 to point at 0
# The dial is rotated L26 to point at 74
# The dial is rotated L74 to point at 0
# The dial is rotated L40 to point at 60
# The dial is rotated L24 to point at 36
# The dial is rotated R63 to point at 99
# The dial is rotated R1 to point at 0
# The dial is rotated R44 to point at 44
# The dial is rotated R56 to point at 0
# The dial is rotated R3 to point at 3
# The dial is rotated L10 to point at 93
# The dial is rotated L44 to point at 49
# The dial is rotated L57 to point at 92
# The dial is rotated R10 to point at 2
# The dial is rotated L83 to point at 19
# The dial is rotated R51 to point at 70
# The dial is rotated R76 to point at 46
# The dial is rotated R54 to point at 0
# The dial is rotated L69 to point at 31
# The dial is rotated L27 to point at 4
# The dial is rotated L4 to point at 0
# The dial is rotated L26 to point at 74
# The dial is rotated L32 to point at 42
# The dial is rotated L39 to point at 3
# The dial is rotated L24 to point at 79
# The dial is rotated L13 to point at 66
# The dial is rotated L42 to point at 24
# The dial is rotated R27 to point at 51
# The dial is rotated L26 to point at 25
# The dial is rotated L4 to point at 21
# The dial is rotated R22 to point at 43
# The dial is rotated L50 to point at 93
# The dial is rotated R18 to point at 11
# The dial is rotated L13 to point at 98
# The dial is rotated R43 to point at 41
# The dial is rotated R24 to point at 65
# The dial is rotated R28 to point at 93
# The dial is rotated L24 to point at 69
# The dial is rotated R45 to point at 14
# The dial is rotated L17 to point at 97
# The dial is rotated L19 to point at 78
# The dial is rotated L22 to point at 56
# The dial is rotated R39 to point at 95
# The dial is rotated R44 to point at 39
# The dial is rotated L4 to point at 35
# The dial is rotated R42 to point at 77
# The dial is rotated L20 to point at 57
# The dial is rotated L26 to point at 31
# The dial is rotated L49 to point at 82
# The dial is rotated L28 to point at 54
# The dial is rotated R30 to point at 84
# The dial is rotated L10 to point at 74
# The dial is rotated L29 to point at 45
# The dial is rotated R6 to point at 51
# The dial is rotated R26 to point at 77
# The dial is rotated L28 to point at 49
# The dial is rotated L34 to point at 15
# The dial is rotated R14 to point at 29
# The dial is rotated L28 to point at 1
# The dial is rotated L28 to point at 73
# The dial is rotated R6 to point at 79
# The dial is rotated R23 to point at 2
# The dial is rotated L28 to point at 74
# The dial is rotated R33 to point at 7
# The dial is rotated L19 to point at 88
# The dial is rotated R6 to point at 94
# The dial is rotated L22 to point at 72
# The dial is rotated R42 to point at 14
# The dial is rotated L14 to point at 0
# The dial is rotated L41 to point at 59
# The dial is rotated L5 to point at 54
# we had 1195 zeros
# 0

# %% [markdown]
# ## PART TWO:

# %%
def rollover(x: int):
    if x > 99:
        return x-100, 1
    elif x < 0:
        return (100 + x), 1 # adding the negative is the same as substracting
    else:
        return x, 0

def do_instruction(loc, instruction):
    direction = instruction[0]
    amount = int(instruction[1:])
    n_zeros = 0

    while amount > 100: # deal with full rotations
        amount -= 100
        n_zeros+=1

    if direction == "R":
        new_loc, n_zeros_rollover = rollover(loc+amount)
    elif direction == "L":
        new_loc, n_zeros_rollover = rollover(loc-amount)

    if n_zeros_rollover>0 and loc == 0: # deal with starting at 0
        n_zeros_rollover -= 1
    elif n_zeros_rollover>0 and new_loc == 0: # deal with arriving at 0
        n_zeros_rollover -= 1

    
    s = f"The dial is rotated {instruction} to point at {new_loc}"
    if n_zeros_rollover:
        s+=f", during this rotation the dial points at zero {n_zeros_rollover} times"
    print(s)   
    loc = new_loc
    n_zeros += n_zeros_rollover
    return loc, n_zeros

def open_safe(data, start_position):
    sequence = [start_position]
    loc = start_position
    n_zeros = 0
    print(f"The dial starts at {loc}")
    for instruction in data:
        loc, n_zeros_while_spinning = do_instruction(loc, instruction)
        sequence.append(loc)
        n_zeros += n_zeros_while_spinning
    print(f"we had {n_zeros} zeros during spinning")
    print(f"We have {sequence.count(0)} zeros visited")
    print(f"We have had {n_zeros+sequence.count(0)} clicks ending on 0 total")
    return sequence, n_zeros

# %%
open_safe(test_data, 50);
# Out:
# The dial starts at 50
# The dial is rotated L68 to point at 82, during this rotation the dial points at zero 1 times
# The dial is rotated L30 to point at 52
# The dial is rotated R48 to point at 0
# The dial is rotated L5 to point at 95
# The dial is rotated R60 to point at 55, during this rotation the dial points at zero 1 times
# The dial is rotated L55 to point at 0
# The dial is rotated L1 to point at 99
# The dial is rotated L99 to point at 0
# The dial is rotated R14 to point at 14
# The dial is rotated L82 to point at 32, during this rotation the dial points at zero 1 times
# we had 3 zeros during spinning
# We have 3 zeros visited
# We have had 6 clicks ending on 0 total

# %%
open_safe(data, 50);
# Out:
# The dial starts at 50
# The dial is rotated L1 to point at 49
# The dial is rotated R43 to point at 92
# The dial is rotated R6 to point at 98
# The dial is rotated R50 to point at 48, during this rotation the dial points at zero 1 times
# The dial is rotated R47 to point at 95
# The dial is rotated R18 to point at 13, during this rotation the dial points at zero 1 times
# The dial is rotated L12 to point at 1
# The dial is rotated L21 to point at 80, during this rotation the dial points at zero 1 times
# The dial is rotated R21 to point at 1, during this rotation the dial points at zero 1 times
# The dial is rotated R38 to point at 39
# The dial is rotated R15 to point at 54
# The dial is rotated R1 to point at 55
# The dial is rotated L19 to point at 36
# The dial is rotated R36 to point at 72
# The dial is rotated L33 to point at 39
# The dial is rotated R25 to point at 64
# The dial is rotated L6 to point at 58
# The dial is rotated R25 to point at 83
# The dial is rotated L7 to point at 76
# The dial is rotated L44 to point at 32
# The dial is rotated R16 to point at 48
# The dial is rotated L43 to point at 5
# The dial is rotated R27 to point at 32
# The dial is rotated L26 to point at 6
# The dial is rotated R17 to point at 23
# The dial is rotated R32 to point at 55
# The dial is rotated R49 to point at 4, during this rotation the dial points at zero 1 times
# The dial is rotated L39 to point at 65, during this rotation the dial points at zero 1 times
# The dial is rotated R22 to point at 87
# The dial is rotated L1 to point at 86
# The dial is rotated L10 to point at 76
# The dial is rotated R24 to point at 0
# The dial is rotated L23 to point at 77
# The dial is rotated R10 to point at 87
# The dial is rotated R13 to point at 0
# The dial is rotated L34 to point at 66
# The dial is rotated L34 to point at 32
# The dial is rotated L32 to point at 0
# The dial is rotated R2 to point at 2
# The dial is rotated L14 to point at 88, during this rotation the dial points at zero 1 times
# The dial is rotated L26 to point at 62
# The dial is rotated L46 to point at 16
# The dial is rotated L42 to point at 74, during this rotation the dial points at zero 1 times
# The dial is rotated R35 to point at 9, during this rotation the dial points at zero 1 times
# The dial is rotated R21 to point at 30
# The dial is rotated R38 to point at 68
# The dial is rotated L8 to point at 60
# The dial is rotated L15 to point at 45
# The dial is rotated L29 to point at 16
# The dial is rotated L52 to point at 64, during this rotation the dial points at zero 1 times
# The dial is rotated L10 to point at 54
# The dial is rotated L54 to point at 0
# The dial is rotated R7 to point at 7
# The dial is rotated R35 to point at 42
# The dial is rotated L16 to point at 26
# The dial is rotated L99 to point at 27, during this rotation the dial points at zero 1 times
# The dial is rotated L60 to point at 67, during this rotation the dial points at zero 1 times
# The dial is rotated R33 to point at 0
# The dial is rotated L38 to point at 62
# The dial is rotated L62 to point at 0
# The dial is rotated L5 to point at 95
# The dial is rotated L42 to point at 53
# The dial is rotated L53 to point at 0
# The dial is rotated R33 to point at 33
# The dial is rotated L68 to point at 65, during this rotation the dial points at zero 1 times
# The dial is rotated L27 to point at 38
# The dial is rotated R19 to point at 57
# The dial is rotated L57 to point at 0
# The dial is rotated R36 to point at 36
# The dial is rotated R64 to point at 0
# The dial is rotated L27 to point at 73
# The dial is rotated R84 to point at 57, during this rotation the dial points at zero 1 times
# The dial is rotated R32 to point at 89
# The dial is rotated R11 to point at 0
# The dial is rotated L39 to point at 61
# The dial is rotated L22 to point at 39
# The dial is rotated L11 to point at 28
# The dial is rotated R72 to point at 0
# The dial is rotated R78 to point at 78
# The dial is rotated L3 to point at 75
# The dial is rotated L75 to point at 0
# The dial is rotated L52 to point at 48
# The dial is rotated R71 to point at 19, during this rotation the dial points at zero 1 times
# The dial is rotated R81 to point at 0
# The dial is rotated R59 to point at 59
# The dial is rotated L73 to point at 86, during this rotation the dial points at zero 1 times
# The dial is rotated R62 to point at 48, during this rotation the dial points at zero 1 times
# The dial is rotated L57 to point at 91, during this rotation the dial points at zero 1 times
# The dial is rotated L56 to point at 35
# The dial is rotated L99 to point at 36, during this rotation the dial points at zero 1 times
# The dial is rotated R64 to point at 0
# The dial is rotated R63 to point at 63
# The dial is rotated R64 to point at 27, during this rotation the dial points at zero 1 times
# The dial is rotated L77 to point at 50, during this rotation the dial points at zero 1 times
# The dial is rotated L50 to point at 0
# The dial is rotated R57 to point at 57
# The dial is rotated R43 to point at 0
# The dial is rotated R86 to point at 86
# The dial is rotated L86 to point at 0
# The dial is rotated R9 to point at 9
# The dial is rotated L9 to point at 0
# The dial is rotated R95 to point at 95
# The dial is rotated R430 to point at 25, during this rotation the dial points at zero 1 times
# The dial is rotated L5 to point at 20
# The dial is rotated R27 to point at 47
# The dial is rotated R86 to point at 33, during this rotation the dial points at zero 1 times
# The dial is rotated R67 to point at 0
# The dial is rotated L97 to point at 3
# The dial is rotated L29 to point at 74, during this rotation the dial points at zero 1 times
# The dial is rotated L993 to point at 81, during this rotation the dial points at zero 1 times
# The dial is rotated L14 to point at 67
# The dial is rotated L27 to point at 40
# The dial is rotated R21 to point at 61
# The dial is rotated L205 to point at 56
# The dial is rotated R913 to point at 69
# The dial is rotated R74 to point at 43, during this rotation the dial points at zero 1 times
# The dial is rotated R57 to point at 0
# The dial is rotated R63 to point at 63
# The dial is rotated L754 to point at 9
# The dial is rotated R791 to point at 0
# The dial is rotated L21 to point at 79
# The dial is rotated L28 to point at 51
# The dial is rotated R91 to point at 42, during this rotation the dial points at zero 1 times
# The dial is rotated L63 to point at 79, during this rotation the dial points at zero 1 times
# The dial is rotated L79 to point at 0
# The dial is rotated R61 to point at 61
# The dial is rotated R61 to point at 22, during this rotation the dial points at zero 1 times
# The dial is rotated L622 to point at 0
# The dial is rotated L58 to point at 42
# The dial is rotated L69 to point at 73, during this rotation the dial points at zero 1 times
# The dial is rotated R879 to point at 52, during this rotation the dial points at zero 1 times
# The dial is rotated L64 to point at 88, during this rotation the dial points at zero 1 times
# The dial is rotated L718 to point at 70
# The dial is rotated L23 to point at 47
# The dial is rotated L47 to point at 0
# The dial is rotated R26 to point at 26
# The dial is rotated R74 to point at 0
# The dial is rotated R30 to point at 30
# The dial is rotated R46 to point at 76
# The dial is rotated R74 to point at 50, during this rotation the dial points at zero 1 times
# The dial is rotated R850 to point at 0
# The dial is rotated R53 to point at 53
# The dial is rotated L775 to point at 78, during this rotation the dial points at zero 1 times
# The dial is rotated L78 to point at 0
# The dial is rotated R8 to point at 8
# The dial is rotated L21 to point at 87, during this rotation the dial points at zero 1 times
# The dial is rotated R713 to point at 0
# The dial is rotated L95 to point at 5
# The dial is rotated L27 to point at 78, during this rotation the dial points at zero 1 times
# The dial is rotated R37 to point at 15, during this rotation the dial points at zero 1 times
# The dial is rotated L9 to point at 6
# The dial is rotated L36 to point at 70, during this rotation the dial points at zero 1 times
# The dial is rotated R10 to point at 80
# The dial is rotated L96 to point at 84, during this rotation the dial points at zero 1 times
# The dial is rotated R34 to point at 18, during this rotation the dial points at zero 1 times
# The dial is rotated L27 to point at 91, during this rotation the dial points at zero 1 times
# The dial is rotated L36 to point at 55
# The dial is rotated R45 to point at 0
# The dial is rotated R33 to point at 33
# The dial is rotated L93 to point at 40, during this rotation the dial points at zero 1 times
# The dial is rotated R60 to point at 0
# The dial is rotated L97 to point at 3
# The dial is rotated R3 to point at 6
# The dial is rotated R94 to point at 0
# The dial is rotated R8 to point at 8
# The dial is rotated R50 to point at 58
# The dial is rotated R67 to point at 25, during this rotation the dial points at zero 1 times
# The dial is rotated R975 to point at 0
# The dial is rotated R83 to point at 83
# The dial is rotated L27 to point at 56
# The dial is rotated L42 to point at 14
# The dial is rotated R86 to point at 0
# The dial is rotated R904 to point at 4
# The dial is rotated L30 to point at 74, during this rotation the dial points at zero 1 times
# The dial is rotated L81 to point at 93, during this rotation the dial points at zero 1 times
# The dial is rotated R7 to point at 0
# The dial is rotated L43 to point at 57
# The dial is rotated R612 to point at 69
# The dial is rotated L67 to point at 2
# The dial is rotated L7 to point at 95, during this rotation the dial points at zero 1 times
# The dial is rotated R45 to point at 40, during this rotation the dial points at zero 1 times
# The dial is rotated R63 to point at 3, during this rotation the dial points at zero 1 times
# The dial is rotated R97 to point at 0
# The dial is rotated R41 to point at 41
# The dial is rotated R29 to point at 70
# The dial is rotated L224 to point at 46
# The dial is rotated R56 to point at 2, during this rotation the dial points at zero 1 times
# The dial is rotated L38 to point at 64, during this rotation the dial points at zero 1 times
# The dial is rotated L64 to point at 0
# The dial is rotated R63 to point at 63
# The dial is rotated L21 to point at 42
# The dial is rotated L94 to point at 48, during this rotation the dial points at zero 1 times
# The dial is rotated R52 to point at 0
# The dial is rotated L61 to point at 39
# The dial is rotated L39 to point at 0
# The dial is rotated R892 to point at 92
# The dial is rotated L92 to point at 0
# The dial is rotated R775 to point at 75
# The dial is rotated L28 to point at 47
# The dial is rotated R91 to point at 38, during this rotation the dial points at zero 1 times
# The dial is rotated R70 to point at 8, during this rotation the dial points at zero 1 times
# The dial is rotated R87 to point at 95
# The dial is rotated L52 to point at 43
# The dial is rotated R57 to point at 0
# The dial is rotated R97 to point at 97
# The dial is rotated L27 to point at 70
# The dial is rotated L97 to point at 73, during this rotation the dial points at zero 1 times
# The dial is rotated L673 to point at 0
# The dial is rotated R44 to point at 44
# The dial is rotated R63 to point at 7, during this rotation the dial points at zero 1 times
# The dial is rotated L96 to point at 11, during this rotation the dial points at zero 1 times
# The dial is rotated L7 to point at 4
# The dial is rotated L36 to point at 68, during this rotation the dial points at zero 1 times
# The dial is rotated R2 to point at 70
# The dial is rotated R25 to point at 95
# The dial is rotated R44 to point at 39, during this rotation the dial points at zero 1 times
# The dial is rotated L54 to point at 85, during this rotation the dial points at zero 1 times
# The dial is rotated L85 to point at 0
# The dial is rotated L89 to point at 11
# The dial is rotated L61 to point at 50, during this rotation the dial points at zero 1 times
# The dial is rotated R50 to point at 0
# The dial is rotated R17 to point at 17
# The dial is rotated L35 to point at 82, during this rotation the dial points at zero 1 times
# The dial is rotated L382 to point at 0
# The dial is rotated R67 to point at 67
# The dial is rotated L928 to point at 39
# The dial is rotated L12 to point at 27
# The dial is rotated L553 to point at 74, during this rotation the dial points at zero 1 times
# The dial is rotated R26 to point at 0
# The dial is rotated R7 to point at 7
# The dial is rotated R93 to point at 0
# The dial is rotated L10 to point at 90
# The dial is rotated R10 to point at 0
# The dial is rotated R92 to point at 92
# The dial is rotated R257 to point at 49, during this rotation the dial points at zero 1 times
# The dial is rotated L5 to point at 44
# The dial is rotated R72 to point at 16, during this rotation the dial points at zero 1 times
# The dial is rotated R84 to point at 0
# The dial is rotated L98 to point at 2
# The dial is rotated L2 to point at 0
# The dial is rotated L823 to point at 77
# The dial is rotated R85 to point at 62, during this rotation the dial points at zero 1 times
# The dial is rotated L50 to point at 12
# The dial is rotated L412 to point at 0
# The dial is rotated L80 to point at 20
# The dial is rotated R227 to point at 47
# The dial is rotated L354 to point at 93, during this rotation the dial points at zero 1 times
# The dial is rotated L93 to point at 0
# The dial is rotated L4 to point at 96
# The dial is rotated L796 to point at 0
# The dial is rotated L834 to point at 66
# The dial is rotated R62 to point at 28, during this rotation the dial points at zero 1 times
# The dial is rotated L903 to point at 25
# The dial is rotated L46 to point at 79, during this rotation the dial points at zero 1 times
# The dial is rotated L79 to point at 0
# The dial is rotated R428 to point at 28
# The dial is rotated L28 to point at 0
# The dial is rotated L20 to point at 80
# The dial is rotated L139 to point at 41
# The dial is rotated L41 to point at 0
# The dial is rotated R82 to point at 82
# The dial is rotated R18 to point at 0
# The dial is rotated R87 to point at 87
# The dial is rotated R99 to point at 86, during this rotation the dial points at zero 1 times
# The dial is rotated R14 to point at 0
# The dial is rotated R970 to point at 70
# The dial is rotated R30 to point at 0
# The dial is rotated L58 to point at 42
# The dial is rotated L54 to point at 88, during this rotation the dial points at zero 1 times
# The dial is rotated L29 to point at 59
# The dial is rotated L54 to point at 5
# The dial is rotated L5 to point at 0
# The dial is rotated R43 to point at 43
# The dial is rotated L685 to point at 58, during this rotation the dial points at zero 1 times
# The dial is rotated R542 to point at 0
# The dial is rotated R618 to point at 18
# The dial is rotated R482 to point at 0
# The dial is rotated L536 to point at 64
# The dial is rotated L43 to point at 21
# The dial is rotated R36 to point at 57
# The dial is rotated R27 to point at 84
# The dial is rotated L84 to point at 0
# The dial is rotated R37 to point at 37
# The dial is rotated L14 to point at 23
# The dial is rotated L14 to point at 9
# The dial is rotated L73 to point at 36, during this rotation the dial points at zero 1 times
# The dial is rotated R5 to point at 41
# The dial is rotated L41 to point at 0
# The dial is rotated L21 to point at 79
# The dial is rotated L779 to point at 0
# The dial is rotated R39 to point at 39
# The dial is rotated R61 to point at 0
# The dial is rotated L99 to point at 1
# The dial is rotated L58 to point at 43, during this rotation the dial points at zero 1 times
# The dial is rotated L484 to point at 59, during this rotation the dial points at zero 1 times
# The dial is rotated R3 to point at 62
# The dial is rotated L36 to point at 26
# The dial is rotated R37 to point at 63
# The dial is rotated L99 to point at 64, during this rotation the dial points at zero 1 times
# The dial is rotated L64 to point at 0
# The dial is rotated R94 to point at 94
# The dial is rotated R34 to point at 28, during this rotation the dial points at zero 1 times
# The dial is rotated L28 to point at 0
# The dial is rotated L9 to point at 91
# The dial is rotated R45 to point at 36, during this rotation the dial points at zero 1 times
# The dial is rotated L23 to point at 13
# The dial is rotated L65 to point at 48, during this rotation the dial points at zero 1 times
# The dial is rotated R91 to point at 39, during this rotation the dial points at zero 1 times
# The dial is rotated R61 to point at 0
# The dial is rotated L880 to point at 20
# The dial is rotated L16 to point at 4
# The dial is rotated L104 to point at 0
# The dial is rotated R76 to point at 76
# The dial is rotated R23 to point at 99
# The dial is rotated R1 to point at 0
# The dial is rotated R149 to point at 49
# The dial is rotated L47 to point at 2
# The dial is rotated R70 to point at 72
# The dial is rotated R14 to point at 86
# The dial is rotated L16 to point at 70
# The dial is rotated R81 to point at 51, during this rotation the dial points at zero 1 times
# The dial is rotated R49 to point at 0
# The dial is rotated L33 to point at 67
# The dial is rotated L67 to point at 0
# The dial is rotated R677 to point at 77
# The dial is rotated L77 to point at 0
# The dial is rotated L420 to point at 80
# The dial is rotated R120 to point at 0
# The dial is rotated R59 to point at 59
# The dial is rotated L59 to point at 0
# The dial is rotated R90 to point at 90
# The dial is rotated L47 to point at 43
# The dial is rotated L37 to point at 6
# The dial is rotated L6 to point at 0
# The dial is rotated R71 to point at 71
# The dial is rotated L71 to point at 0
# The dial is rotated R82 to point at 82
# The dial is rotated R78 to point at 60, during this rotation the dial points at zero 1 times
# The dial is rotated R40 to point at 0
# The dial is rotated R39 to point at 39
# The dial is rotated L54 to point at 85, during this rotation the dial points at zero 1 times
# The dial is rotated R82 to point at 67, during this rotation the dial points at zero 1 times
# The dial is rotated L9 to point at 58
# The dial is rotated R2 to point at 60
# The dial is rotated R41 to point at 1, during this rotation the dial points at zero 1 times
# The dial is rotated R99 to point at 0
# The dial is rotated R9 to point at 9
# The dial is rotated R91 to point at 0
# The dial is rotated L69 to point at 31
# The dial is rotated R69 to point at 0
# The dial is rotated L41 to point at 59
# The dial is rotated R41 to point at 0
# The dial is rotated L482 to point at 18
# The dial is rotated R19 to point at 37
# The dial is rotated R388 to point at 25, during this rotation the dial points at zero 1 times
# The dial is rotated R75 to point at 0
# The dial is rotated L38 to point at 62
# The dial is rotated L62 to point at 0
# The dial is rotated L5 to point at 95
# The dial is rotated R5 to point at 0
# The dial is rotated L46 to point at 54
# The dial is rotated R93 to point at 47, during this rotation the dial points at zero 1 times
# The dial is rotated R645 to point at 92
# The dial is rotated R8 to point at 0
# The dial is rotated R1 to point at 1
# The dial is rotated L1 to point at 0
# The dial is rotated L7 to point at 93
# The dial is rotated L875 to point at 18
# The dial is rotated L807 to point at 11
# The dial is rotated L57 to point at 54, during this rotation the dial points at zero 1 times
# The dial is rotated R46 to point at 0
# The dial is rotated R55 to point at 55
# The dial is rotated R45 to point at 0
# The dial is rotated L89 to point at 11
# The dial is rotated L4 to point at 7
# The dial is rotated R11 to point at 18
# The dial is rotated R26 to point at 44
# The dial is rotated L613 to point at 31
# The dial is rotated R469 to point at 0
# The dial is rotated L60 to point at 40
# The dial is rotated R84 to point at 24, during this rotation the dial points at zero 1 times
# The dial is rotated R69 to point at 93
# The dial is rotated R7 to point at 0
# The dial is rotated R159 to point at 59
# The dial is rotated R24 to point at 83
# The dial is rotated L47 to point at 36
# The dial is rotated R51 to point at 87
# The dial is rotated R13 to point at 0
# The dial is rotated L878 to point at 22
# The dial is rotated L22 to point at 0
# The dial is rotated L220 to point at 80
# The dial is rotated L29 to point at 51
# The dial is rotated R48 to point at 99
# The dial is rotated R29 to point at 28, during this rotation the dial points at zero 1 times
# The dial is rotated L37 to point at 91, during this rotation the dial points at zero 1 times
# The dial is rotated R75 to point at 66, during this rotation the dial points at zero 1 times
# The dial is rotated R42 to point at 8, during this rotation the dial points at zero 1 times
# The dial is rotated R87 to point at 95
# The dial is rotated L95 to point at 0
# The dial is rotated R21 to point at 21
# The dial is rotated R179 to point at 0
# The dial is rotated L188 to point at 12
# The dial is rotated L54 to point at 58, during this rotation the dial points at zero 1 times
# The dial is rotated R42 to point at 0
# The dial is rotated L56 to point at 44
# The dial is rotated L46 to point at 98, during this rotation the dial points at zero 1 times
# The dial is rotated L39 to point at 59
# The dial is rotated L493 to point at 66, during this rotation the dial points at zero 1 times
# The dial is rotated L74 to point at 92, during this rotation the dial points at zero 1 times
# The dial is rotated R9 to point at 1, during this rotation the dial points at zero 1 times
# The dial is rotated L81 to point at 20, during this rotation the dial points at zero 1 times
# The dial is rotated R24 to point at 44
# The dial is rotated L28 to point at 16
# The dial is rotated L57 to point at 59, during this rotation the dial points at zero 1 times
# The dial is rotated L46 to point at 13
# The dial is rotated L13 to point at 0
# The dial is rotated R11 to point at 11
# The dial is rotated L22 to point at 89, during this rotation the dial points at zero 1 times
# The dial is rotated L96 to point at 93, during this rotation the dial points at zero 1 times
# The dial is rotated R7 to point at 0
# The dial is rotated L94 to point at 6
# The dial is rotated L82 to point at 24, during this rotation the dial points at zero 1 times
# The dial is rotated R99 to point at 23, during this rotation the dial points at zero 1 times
# The dial is rotated R12 to point at 35
# The dial is rotated R65 to point at 0
# The dial is rotated L83 to point at 17
# The dial is rotated L17 to point at 0
# The dial is rotated L47 to point at 53
# The dial is rotated L53 to point at 0
# The dial is rotated L263 to point at 37
# The dial is rotated L46 to point at 91, during this rotation the dial points at zero 1 times
# The dial is rotated L5 to point at 86
# The dial is rotated R714 to point at 0
# The dial is rotated R990 to point at 90
# The dial is rotated R14 to point at 4, during this rotation the dial points at zero 1 times
# The dial is rotated L53 to point at 51, during this rotation the dial points at zero 1 times
# The dial is rotated L36 to point at 15
# The dial is rotated R85 to point at 0
# The dial is rotated L3 to point at 97
# The dial is rotated L97 to point at 0
# The dial is rotated L66 to point at 34
# The dial is rotated R766 to point at 0
# The dial is rotated L61 to point at 39
# The dial is rotated R661 to point at 0
# The dial is rotated L25 to point at 75
# The dial is rotated L5 to point at 70
# The dial is rotated R65 to point at 35, during this rotation the dial points at zero 1 times
# The dial is rotated L75 to point at 60, during this rotation the dial points at zero 1 times
# The dial is rotated L560 to point at 0
# The dial is rotated R72 to point at 72
# The dial is rotated R556 to point at 28, during this rotation the dial points at zero 1 times
# The dial is rotated R9 to point at 37
# The dial is rotated L7 to point at 30
# The dial is rotated R170 to point at 0
# The dial is rotated R20 to point at 20
# The dial is rotated R40 to point at 60
# The dial is rotated L860 to point at 0
# The dial is rotated L21 to point at 79
# The dial is rotated R50 to point at 29, during this rotation the dial points at zero 1 times
# The dial is rotated R524 to point at 53
# The dial is rotated R47 to point at 0
# The dial is rotated L304 to point at 96
# The dial is rotated R12 to point at 8, during this rotation the dial points at zero 1 times
# The dial is rotated R41 to point at 49
# The dial is rotated L55 to point at 94, during this rotation the dial points at zero 1 times
# The dial is rotated L5 to point at 89
# The dial is rotated L48 to point at 41
# The dial is rotated R428 to point at 69
# The dial is rotated R313 to point at 82
# The dial is rotated R68 to point at 50, during this rotation the dial points at zero 1 times
# The dial is rotated R410 to point at 60
# The dial is rotated R2 to point at 62
# The dial is rotated L687 to point at 75, during this rotation the dial points at zero 1 times
# The dial is rotated R25 to point at 0
# The dial is rotated R37 to point at 37
# The dial is rotated R22 to point at 59
# The dial is rotated R12 to point at 71
# The dial is rotated L9 to point at 62
# The dial is rotated R38 to point at 0
# The dial is rotated R54 to point at 54
# The dial is rotated R243 to point at 97
# The dial is rotated L89 to point at 8
# The dial is rotated L8 to point at 0
# The dial is rotated R29 to point at 29
# The dial is rotated L66 to point at 63, during this rotation the dial points at zero 1 times
# The dial is rotated L63 to point at 0
# The dial is rotated L815 to point at 85
# The dial is rotated R115 to point at 0
# The dial is rotated L69 to point at 31
# The dial is rotated R71 to point at 2, during this rotation the dial points at zero 1 times
# The dial is rotated R98 to point at 0
# The dial is rotated R70 to point at 70
# The dial is rotated R31 to point at 1, during this rotation the dial points at zero 1 times
# The dial is rotated L22 to point at 79, during this rotation the dial points at zero 1 times
# The dial is rotated R21 to point at 0
# The dial is rotated R47 to point at 47
# The dial is rotated R16 to point at 63
# The dial is rotated R37 to point at 0
# The dial is rotated L80 to point at 20
# The dial is rotated L65 to point at 55, during this rotation the dial points at zero 1 times
# The dial is rotated R45 to point at 0
# The dial is rotated R55 to point at 55
# The dial is rotated L355 to point at 0
# The dial is rotated L23 to point at 77
# The dial is rotated L48 to point at 29
# The dial is rotated R93 to point at 22, during this rotation the dial points at zero 1 times
# The dial is rotated R78 to point at 0
# The dial is rotated L23 to point at 77
# The dial is rotated L44 to point at 33
# The dial is rotated R24 to point at 57
# The dial is rotated L38 to point at 19
# The dial is rotated L7 to point at 12
# The dial is rotated L12 to point at 0
# The dial is rotated R73 to point at 73
# The dial is rotated L67 to point at 6
# The dial is rotated R94 to point at 0
# The dial is rotated L13 to point at 87
# The dial is rotated L87 to point at 0
# The dial is rotated R31 to point at 31
# The dial is rotated L59 to point at 72, during this rotation the dial points at zero 1 times
# The dial is rotated R54 to point at 26, during this rotation the dial points at zero 1 times
# The dial is rotated R180 to point at 6, during this rotation the dial points at zero 1 times
# The dial is rotated L404 to point at 2
# The dial is rotated L776 to point at 26, during this rotation the dial points at zero 1 times
# The dial is rotated R36 to point at 62
# The dial is rotated L590 to point at 72, during this rotation the dial points at zero 1 times
# The dial is rotated R28 to point at 0
# The dial is rotated L77 to point at 23
# The dial is rotated L914 to point at 9
# The dial is rotated R54 to point at 63
# The dial is rotated L963 to point at 0
# The dial is rotated R70 to point at 70
# The dial is rotated R13 to point at 83
# The dial is rotated R517 to point at 0
# The dial is rotated L46 to point at 54
# The dial is rotated R46 to point at 0
# The dial is rotated L13 to point at 87
# The dial is rotated L28 to point at 59
# The dial is rotated R38 to point at 97
# The dial is rotated R39 to point at 36, during this rotation the dial points at zero 1 times
# The dial is rotated L36 to point at 0
# The dial is rotated R33 to point at 33
# The dial is rotated L33 to point at 0
# The dial is rotated R689 to point at 89
# The dial is rotated R85 to point at 74, during this rotation the dial points at zero 1 times
# The dial is rotated R56 to point at 30, during this rotation the dial points at zero 1 times
# The dial is rotated R615 to point at 45
# The dial is rotated L45 to point at 0
# The dial is rotated L51 to point at 49
# The dial is rotated R812 to point at 61
# The dial is rotated R39 to point at 0
# The dial is rotated R83 to point at 83
# The dial is rotated L686 to point at 97, during this rotation the dial points at zero 1 times
# The dial is rotated L49 to point at 48
# The dial is rotated L48 to point at 0
# The dial is rotated L82 to point at 18
# The dial is rotated L52 to point at 66, during this rotation the dial points at zero 1 times
# The dial is rotated R34 to point at 0
# The dial is rotated R52 to point at 52
# The dial is rotated R88 to point at 40, during this rotation the dial points at zero 1 times
# The dial is rotated L71 to point at 69, during this rotation the dial points at zero 1 times
# The dial is rotated L69 to point at 0
# The dial is rotated R46 to point at 46
# The dial is rotated R54 to point at 0
# The dial is rotated L17 to point at 83
# The dial is rotated R17 to point at 0
# The dial is rotated R70 to point at 70
# The dial is rotated L70 to point at 0
# The dial is rotated L641 to point at 59
# The dial is rotated L362 to point at 97, during this rotation the dial points at zero 1 times
# The dial is rotated R17 to point at 14, during this rotation the dial points at zero 1 times
# The dial is rotated L6 to point at 8
# The dial is rotated L8 to point at 0
# The dial is rotated R4 to point at 4
# The dial is rotated R96 to point at 0
# The dial is rotated R514 to point at 14
# The dial is rotated L20 to point at 94, during this rotation the dial points at zero 1 times
# The dial is rotated L75 to point at 19
# The dial is rotated R37 to point at 56
# The dial is rotated R37 to point at 93
# The dial is rotated R7 to point at 0
# The dial is rotated L74 to point at 26
# The dial is rotated R56 to point at 82
# The dial is rotated L51 to point at 31
# The dial is rotated L31 to point at 0
# The dial is rotated R42 to point at 42
# The dial is rotated R94 to point at 36, during this rotation the dial points at zero 1 times
# The dial is rotated L25 to point at 11
# The dial is rotated L11 to point at 0
# The dial is rotated L31 to point at 69
# The dial is rotated L8 to point at 61
# The dial is rotated L761 to point at 0
# The dial is rotated R26 to point at 26
# The dial is rotated R74 to point at 0
# The dial is rotated L102 to point at 98
# The dial is rotated R2 to point at 0
# The dial is rotated L67 to point at 33
# The dial is rotated R3 to point at 36
# The dial is rotated R94 to point at 30, during this rotation the dial points at zero 1 times
# The dial is rotated R95 to point at 25, during this rotation the dial points at zero 1 times
# The dial is rotated L47 to point at 78, during this rotation the dial points at zero 1 times
# The dial is rotated L19 to point at 59
# The dial is rotated L19 to point at 40
# The dial is rotated L40 to point at 0
# The dial is rotated R177 to point at 77
# The dial is rotated L37 to point at 40
# The dial is rotated L40 to point at 0
# The dial is rotated L46 to point at 54
# The dial is rotated R20 to point at 74
# The dial is rotated R126 to point at 0
# The dial is rotated R89 to point at 89
# The dial is rotated R40 to point at 29, during this rotation the dial points at zero 1 times
# The dial is rotated R17 to point at 46
# The dial is rotated R876 to point at 22, during this rotation the dial points at zero 1 times
# The dial is rotated R251 to point at 73
# The dial is rotated L37 to point at 36
# The dial is rotated R758 to point at 94
# The dial is rotated R6 to point at 0
# The dial is rotated R96 to point at 96
# The dial is rotated L20 to point at 76
# The dial is rotated R24 to point at 0
# The dial is rotated R472 to point at 72
# The dial is rotated R28 to point at 0
# The dial is rotated L83 to point at 17
# The dial is rotated L17 to point at 0
# The dial is rotated R588 to point at 88
# The dial is rotated L244 to point at 44
# The dial is rotated R312 to point at 56
# The dial is rotated R15 to point at 71
# The dial is rotated R13 to point at 84
# The dial is rotated L284 to point at 0
# The dial is rotated L36 to point at 64
# The dial is rotated L20 to point at 44
# The dial is rotated L820 to point at 24
# The dial is rotated L14 to point at 10
# The dial is rotated R74 to point at 84
# The dial is rotated L84 to point at 0
# The dial is rotated L49 to point at 51
# The dial is rotated R49 to point at 0
# The dial is rotated L92 to point at 8
# The dial is rotated R86 to point at 94
# The dial is rotated R59 to point at 53, during this rotation the dial points at zero 1 times
# The dial is rotated R181 to point at 34, during this rotation the dial points at zero 1 times
# The dial is rotated R66 to point at 0
# The dial is rotated L74 to point at 26
# The dial is rotated R637 to point at 63
# The dial is rotated R52 to point at 15, during this rotation the dial points at zero 1 times
# The dial is rotated L15 to point at 0
# The dial is rotated L21 to point at 79
# The dial is rotated R21 to point at 0
# The dial is rotated R83 to point at 83
# The dial is rotated R12 to point at 95
# The dial is rotated R5 to point at 0
# The dial is rotated L83 to point at 17
# The dial is rotated R201 to point at 18
# The dial is rotated R31 to point at 49
# The dial is rotated L63 to point at 86, during this rotation the dial points at zero 1 times
# The dial is rotated L45 to point at 41
# The dial is rotated R97 to point at 38, during this rotation the dial points at zero 1 times
# The dial is rotated R22 to point at 60
# The dial is rotated R34 to point at 94
# The dial is rotated R14 to point at 8, during this rotation the dial points at zero 1 times
# The dial is rotated L542 to point at 66, during this rotation the dial points at zero 1 times
# The dial is rotated L29 to point at 37
# The dial is rotated R63 to point at 0
# The dial is rotated L521 to point at 79
# The dial is rotated R12 to point at 91
# The dial is rotated L32 to point at 59
# The dial is rotated L956 to point at 3
# The dial is rotated L21 to point at 82, during this rotation the dial points at zero 1 times
# The dial is rotated R71 to point at 53, during this rotation the dial points at zero 1 times
# The dial is rotated R47 to point at 0
# The dial is rotated R119 to point at 19
# The dial is rotated R81 to point at 0
# The dial is rotated R56 to point at 56
# The dial is rotated L56 to point at 0
# The dial is rotated R610 to point at 10
# The dial is rotated R90 to point at 0
# The dial is rotated R12 to point at 12
# The dial is rotated R408 to point at 20
# The dial is rotated R580 to point at 0
# The dial is rotated L68 to point at 32
# The dial is rotated R99 to point at 31, during this rotation the dial points at zero 1 times
# The dial is rotated L58 to point at 73, during this rotation the dial points at zero 1 times
# The dial is rotated R23 to point at 96
# The dial is rotated R604 to point at 0
# The dial is rotated R72 to point at 72
# The dial is rotated L30 to point at 42
# The dial is rotated L89 to point at 53, during this rotation the dial points at zero 1 times
# The dial is rotated R893 to point at 46, during this rotation the dial points at zero 1 times
# The dial is rotated L54 to point at 92, during this rotation the dial points at zero 1 times
# The dial is rotated L92 to point at 0
# The dial is rotated R51 to point at 51
# The dial is rotated L7 to point at 44
# The dial is rotated R77 to point at 21, during this rotation the dial points at zero 1 times
# The dial is rotated L21 to point at 0
# The dial is rotated L66 to point at 34
# The dial is rotated L55 to point at 79, during this rotation the dial points at zero 1 times
# The dial is rotated L96 to point at 83, during this rotation the dial points at zero 1 times
# The dial is rotated R17 to point at 0
# The dial is rotated R4 to point at 4
# The dial is rotated L842 to point at 62, during this rotation the dial points at zero 1 times
# The dial is rotated L62 to point at 0
# The dial is rotated R53 to point at 53
# The dial is rotated R347 to point at 0
# The dial is rotated L250 to point at 50
# The dial is rotated R50 to point at 0
# The dial is rotated R34 to point at 34
# The dial is rotated R666 to point at 0
# The dial is rotated R4 to point at 4
# The dial is rotated L37 to point at 67, during this rotation the dial points at zero 1 times
# The dial is rotated L724 to point at 43
# The dial is rotated L43 to point at 0
# The dial is rotated R10 to point at 10
# The dial is rotated L110 to point at 0
# The dial is rotated R1 to point at 1
# The dial is rotated L1 to point at 0
# The dial is rotated R331 to point at 31
# The dial is rotated R435 to point at 66
# The dial is rotated R38 to point at 4, during this rotation the dial points at zero 1 times
# The dial is rotated L739 to point at 65, during this rotation the dial points at zero 1 times
# The dial is rotated R82 to point at 47, during this rotation the dial points at zero 1 times
# The dial is rotated R78 to point at 25, during this rotation the dial points at zero 1 times
# The dial is rotated R75 to point at 0
# The dial is rotated R1 to point at 1
# The dial is rotated R99 to point at 0
# The dial is rotated L29 to point at 71
# The dial is rotated L28 to point at 43
# The dial is rotated L906 to point at 37
# The dial is rotated R53 to point at 90
# The dial is rotated R30 to point at 20, during this rotation the dial points at zero 1 times
# The dial is rotated R93 to point at 13, during this rotation the dial points at zero 1 times
# The dial is rotated L19 to point at 94, during this rotation the dial points at zero 1 times
# The dial is rotated L27 to point at 67
# The dial is rotated L67 to point at 0
# The dial is rotated R49 to point at 49
# The dial is rotated L76 to point at 73, during this rotation the dial points at zero 1 times
# The dial is rotated R15 to point at 88
# The dial is rotated L56 to point at 32
# The dial is rotated L76 to point at 56, during this rotation the dial points at zero 1 times
# The dial is rotated R11 to point at 67
# The dial is rotated L70 to point at 97, during this rotation the dial points at zero 1 times
# The dial is rotated R213 to point at 10, during this rotation the dial points at zero 1 times
# The dial is rotated L10 to point at 0
# The dial is rotated R97 to point at 97
# The dial is rotated L438 to point at 59
# The dial is rotated R55 to point at 14, during this rotation the dial points at zero 1 times
# The dial is rotated L22 to point at 92, during this rotation the dial points at zero 1 times
# The dial is rotated R8 to point at 0
# The dial is rotated L42 to point at 58
# The dial is rotated R12 to point at 70
# The dial is rotated L270 to point at 0
# The dial is rotated R82 to point at 82
# The dial is rotated L279 to point at 3
# The dial is rotated L694 to point at 9, during this rotation the dial points at zero 1 times
# The dial is rotated R70 to point at 79
# The dial is rotated R41 to point at 20, during this rotation the dial points at zero 1 times
# The dial is rotated R74 to point at 94
# The dial is rotated L41 to point at 53
# The dial is rotated R71 to point at 24, during this rotation the dial points at zero 1 times
# The dial is rotated L96 to point at 28, during this rotation the dial points at zero 1 times
# The dial is rotated L294 to point at 34, during this rotation the dial points at zero 1 times
# The dial is rotated R59 to point at 93
# The dial is rotated L693 to point at 0
# The dial is rotated L17 to point at 83
# The dial is rotated R815 to point at 98
# The dial is rotated L99 to point at 99, during this rotation the dial points at zero 1 times
# The dial is rotated R19 to point at 18, during this rotation the dial points at zero 1 times
# The dial is rotated R82 to point at 0
# The dial is rotated L81 to point at 19
# The dial is rotated R32 to point at 51
# The dial is rotated L78 to point at 73, during this rotation the dial points at zero 1 times
# The dial is rotated R27 to point at 0
# The dial is rotated L36 to point at 64
# The dial is rotated R17 to point at 81
# The dial is rotated R97 to point at 78, during this rotation the dial points at zero 1 times
# The dial is rotated R32 to point at 10, during this rotation the dial points at zero 1 times
# The dial is rotated R90 to point at 0
# The dial is rotated L85 to point at 15
# The dial is rotated L15 to point at 0
# The dial is rotated L24 to point at 76
# The dial is rotated L76 to point at 0
# The dial is rotated L489 to point at 11
# The dial is rotated R34 to point at 45
# The dial is rotated R355 to point at 0
# The dial is rotated L99 to point at 1
# The dial is rotated L943 to point at 58, during this rotation the dial points at zero 1 times
# The dial is rotated L180 to point at 78, during this rotation the dial points at zero 1 times
# The dial is rotated R22 to point at 0
# The dial is rotated R38 to point at 38
# The dial is rotated R62 to point at 0
# The dial is rotated R39 to point at 39
# The dial is rotated L239 to point at 0
# The dial is rotated L54 to point at 46
# The dial is rotated L67 to point at 79, during this rotation the dial points at zero 1 times
# The dial is rotated L65 to point at 14
# The dial is rotated R81 to point at 95
# The dial is rotated L21 to point at 74
# The dial is rotated R254 to point at 28, during this rotation the dial points at zero 1 times
# The dial is rotated R30 to point at 58
# The dial is rotated R39 to point at 97
# The dial is rotated R992 to point at 89, during this rotation the dial points at zero 1 times
# The dial is rotated L54 to point at 35
# The dial is rotated L182 to point at 53, during this rotation the dial points at zero 1 times
# The dial is rotated L453 to point at 0
# The dial is rotated L31 to point at 69
# The dial is rotated R31 to point at 0
# The dial is rotated L18 to point at 82
# The dial is rotated L2 to point at 80
# The dial is rotated L539 to point at 41
# The dial is rotated R4 to point at 45
# The dial is rotated R71 to point at 16, during this rotation the dial points at zero 1 times
# The dial is rotated L968 to point at 48, during this rotation the dial points at zero 1 times
# The dial is rotated R52 to point at 0
# The dial is rotated R68 to point at 68
# The dial is rotated R32 to point at 0
# The dial is rotated R10 to point at 10
# The dial is rotated R665 to point at 75
# The dial is rotated R86 to point at 61, during this rotation the dial points at zero 1 times
# The dial is rotated R31 to point at 92
# The dial is rotated L83 to point at 9
# The dial is rotated L82 to point at 27, during this rotation the dial points at zero 1 times
# The dial is rotated R73 to point at 0
# The dial is rotated L81 to point at 19
# The dial is rotated L19 to point at 0
# The dial is rotated R714 to point at 14
# The dial is rotated R86 to point at 0
# The dial is rotated R96 to point at 96
# The dial is rotated R4 to point at 0
# The dial is rotated R653 to point at 53
# The dial is rotated L52 to point at 1
# The dial is rotated R920 to point at 21
# The dial is rotated R379 to point at 0
# The dial is rotated R47 to point at 47
# The dial is rotated L8 to point at 39
# The dial is rotated L36 to point at 3
# The dial is rotated R46 to point at 49
# The dial is rotated L49 to point at 0
# The dial is rotated R32 to point at 32
# The dial is rotated L932 to point at 0
# The dial is rotated R50 to point at 50
# The dial is rotated L950 to point at 0
# The dial is rotated L67 to point at 33
# The dial is rotated R405 to point at 38
# The dial is rotated L538 to point at 0
# The dial is rotated L76 to point at 24
# The dial is rotated L24 to point at 0
# The dial is rotated R93 to point at 93
# The dial is rotated R53 to point at 46, during this rotation the dial points at zero 1 times
# The dial is rotated L46 to point at 0
# The dial is rotated R43 to point at 43
# The dial is rotated L543 to point at 0
# The dial is rotated R93 to point at 93
# The dial is rotated R2 to point at 95
# The dial is rotated R6 to point at 1, during this rotation the dial points at zero 1 times
# The dial is rotated R412 to point at 13
# The dial is rotated L93 to point at 20, during this rotation the dial points at zero 1 times
# The dial is rotated L85 to point at 35, during this rotation the dial points at zero 1 times
# The dial is rotated R61 to point at 96
# The dial is rotated L57 to point at 39
# The dial is rotated R76 to point at 15, during this rotation the dial points at zero 1 times
# The dial is rotated L115 to point at 0
# The dial is rotated L67 to point at 33
# The dial is rotated L33 to point at 0
# The dial is rotated L814 to point at 86
# The dial is rotated L62 to point at 24
# The dial is rotated L24 to point at 0
# The dial is rotated R73 to point at 73
# The dial is rotated L73 to point at 0
# The dial is rotated L46 to point at 54
# The dial is rotated L14 to point at 40
# The dial is rotated R125 to point at 65
# The dial is rotated R35 to point at 0
# The dial is rotated R15 to point at 15
# The dial is rotated L31 to point at 84, during this rotation the dial points at zero 1 times
# The dial is rotated L56 to point at 28
# The dial is rotated L28 to point at 0
# The dial is rotated R96 to point at 96
# The dial is rotated L98 to point at 98, during this rotation the dial points at zero 1 times
# The dial is rotated R17 to point at 15, during this rotation the dial points at zero 1 times
# The dial is rotated L15 to point at 0
# The dial is rotated R53 to point at 53
# The dial is rotated R27 to point at 80
# The dial is rotated L80 to point at 0
# The dial is rotated L31 to point at 69
# The dial is rotated R16 to point at 85
# The dial is rotated L74 to point at 11
# The dial is rotated L111 to point at 0
# The dial is rotated L662 to point at 38
# The dial is rotated R353 to point at 91
# The dial is rotated R52 to point at 43, during this rotation the dial points at zero 1 times
# The dial is rotated R92 to point at 35, during this rotation the dial points at zero 1 times
# The dial is rotated L172 to point at 63, during this rotation the dial points at zero 1 times
# The dial is rotated L74 to point at 89, during this rotation the dial points at zero 1 times
# The dial is rotated R11 to point at 0
# The dial is rotated L8 to point at 92
# The dial is rotated L92 to point at 0
# The dial is rotated L4 to point at 96
# The dial is rotated R46 to point at 42, during this rotation the dial points at zero 1 times
# The dial is rotated R41 to point at 83
# The dial is rotated L283 to point at 0
# The dial is rotated R63 to point at 63
# The dial is rotated R26 to point at 89
# The dial is rotated L31 to point at 58
# The dial is rotated L958 to point at 0
# The dial is rotated R28 to point at 28
# The dial is rotated R72 to point at 0
# The dial is rotated L55 to point at 45
# The dial is rotated R43 to point at 88
# The dial is rotated R9 to point at 97
# The dial is rotated L97 to point at 0
# The dial is rotated L8 to point at 92
# The dial is rotated R8 to point at 0
# The dial is rotated R877 to point at 77
# The dial is rotated L44 to point at 33
# The dial is rotated R23 to point at 56
# The dial is rotated L56 to point at 0
# The dial is rotated R75 to point at 75
# The dial is rotated L75 to point at 0
# The dial is rotated L777 to point at 23
# The dial is rotated R1 to point at 24
# The dial is rotated L24 to point at 0
# The dial is rotated L83 to point at 17
# The dial is rotated L17 to point at 0
# The dial is rotated R43 to point at 43
# The dial is rotated R24 to point at 67
# The dial is rotated R1 to point at 68
# The dial is rotated L42 to point at 26
# The dial is rotated L84 to point at 42, during this rotation the dial points at zero 1 times
# The dial is rotated R758 to point at 0
# The dial is rotated L18 to point at 82
# The dial is rotated R63 to point at 45, during this rotation the dial points at zero 1 times
# The dial is rotated R32 to point at 77
# The dial is rotated R71 to point at 48, during this rotation the dial points at zero 1 times
# The dial is rotated L741 to point at 7
# The dial is rotated R85 to point at 92
# The dial is rotated R56 to point at 48, during this rotation the dial points at zero 1 times
# The dial is rotated R55 to point at 3, during this rotation the dial points at zero 1 times
# The dial is rotated L11 to point at 92, during this rotation the dial points at zero 1 times
# The dial is rotated L50 to point at 42
# ...
# The dial is rotated L33 to point at 67
# The dial is rotated L67 to point at 0
# The dial is rotated R83 to point at 83
# The dial is rotated L83 to point at 0
# The dial is rotated R77 to point at 77
# The dial is rotated R36 to point at 13, during this rotation the dial points at zero 1 times
# The dial is rotated L13 to point at 0
# The dial is rotated R87 to point at 87
# The dial is rotated L76 to point at 11
# The dial is rotated R6 to point at 17
# The dial is rotated L62 to point at 55, during this rotation the dial points at zero 1 times
# The dial is rotated R59 to point at 14, during this rotation the dial points at zero 1 times
# The dial is rotated R166 to point at 80
# The dial is rotated R372 to point at 52, during this rotation the dial points at zero 1 times
# The dial is rotated L1 to point at 51
# The dial is rotated L38 to point at 13
# The dial is rotated L13 to point at 0
# The dial is rotated R43 to point at 43
# The dial is rotated R45 to point at 88
# The dial is rotated L88 to point at 0
# The dial is rotated L80 to point at 20
# The dial is rotated L29 to point at 91, during this rotation the dial points at zero 1 times
# The dial is rotated L791 to point at 0
# The dial is rotated L23 to point at 77
# The dial is rotated L77 to point at 0
# The dial is rotated L137 to point at 63
# The dial is rotated R937 to point at 0
# The dial is rotated L61 to point at 39
# The dial is rotated R61 to point at 0
# The dial is rotated L6 to point at 94
# The dial is rotated R57 to point at 51, during this rotation the dial points at zero 1 times
# The dial is rotated R20 to point at 71
# The dial is rotated L71 to point at 0
# The dial is rotated L33 to point at 67
# The dial is rotated L67 to point at 0
# The dial is rotated L89 to point at 11
# The dial is rotated L8 to point at 3
# The dial is rotated R97 to point at 0
# The dial is rotated L7 to point at 93
# The dial is rotated R518 to point at 11, during this rotation the dial points at zero 1 times
# The dial is rotated L11 to point at 0
# The dial is rotated L35 to point at 65
# The dial is rotated L44 to point at 21
# The dial is rotated R52 to point at 73
# The dial is rotated R20 to point at 93
# The dial is rotated R107 to point at 0
# The dial is rotated R76 to point at 76
# The dial is rotated L64 to point at 12
# The dial is rotated L21 to point at 91, during this rotation the dial points at zero 1 times
# The dial is rotated L91 to point at 0
# The dial is rotated L61 to point at 39
# The dial is rotated R261 to point at 0
# The dial is rotated R68 to point at 68
# The dial is rotated R32 to point at 0
# The dial is rotated R57 to point at 57
# The dial is rotated R65 to point at 22, during this rotation the dial points at zero 1 times
# The dial is rotated R78 to point at 0
# The dial is rotated R78 to point at 78
# The dial is rotated L9 to point at 69
# The dial is rotated L57 to point at 12
# The dial is rotated L1 to point at 11
# The dial is rotated L11 to point at 0
# The dial is rotated R64 to point at 64
# The dial is rotated R299 to point at 63, during this rotation the dial points at zero 1 times
# The dial is rotated R67 to point at 30, during this rotation the dial points at zero 1 times
# The dial is rotated R71 to point at 1, during this rotation the dial points at zero 1 times
# The dial is rotated L659 to point at 42, during this rotation the dial points at zero 1 times
# The dial is rotated L534 to point at 8
# The dial is rotated R35 to point at 43
# The dial is rotated L743 to point at 0
# The dial is rotated R16 to point at 16
# The dial is rotated R84 to point at 0
# The dial is rotated R757 to point at 57
# The dial is rotated L39 to point at 18
# The dial is rotated L18 to point at 0
# The dial is rotated R55 to point at 55
# The dial is rotated L93 to point at 62, during this rotation the dial points at zero 1 times
# The dial is rotated R60 to point at 22, during this rotation the dial points at zero 1 times
# The dial is rotated L69 to point at 53, during this rotation the dial points at zero 1 times
# The dial is rotated R47 to point at 0
# The dial is rotated R10 to point at 10
# The dial is rotated L10 to point at 0
# The dial is rotated R69 to point at 69
# The dial is rotated R431 to point at 0
# The dial is rotated R25 to point at 25
# The dial is rotated R413 to point at 38
# The dial is rotated R62 to point at 0
# The dial is rotated L35 to point at 65
# The dial is rotated R544 to point at 9, during this rotation the dial points at zero 1 times
# The dial is rotated R91 to point at 0
# The dial is rotated L2 to point at 98
# The dial is rotated L77 to point at 21
# The dial is rotated L721 to point at 0
# The dial is rotated L55 to point at 45
# The dial is rotated L945 to point at 0
# The dial is rotated L94 to point at 6
# The dial is rotated R327 to point at 33
# The dial is rotated R814 to point at 47
# The dial is rotated R55 to point at 2, during this rotation the dial points at zero 1 times
# The dial is rotated L79 to point at 23, during this rotation the dial points at zero 1 times
# The dial is rotated R768 to point at 91
# The dial is rotated L91 to point at 0
# The dial is rotated L92 to point at 8
# The dial is rotated L11 to point at 97, during this rotation the dial points at zero 1 times
# The dial is rotated L26 to point at 71
# The dial is rotated R29 to point at 0
# The dial is rotated L98 to point at 2
# The dial is rotated R254 to point at 56
# The dial is rotated R24 to point at 80
# The dial is rotated L45 to point at 35
# The dial is rotated R65 to point at 0
# The dial is rotated R10 to point at 10
# The dial is rotated L13 to point at 97, during this rotation the dial points at zero 1 times
# The dial is rotated R203 to point at 0
# The dial is rotated L31 to point at 69
# The dial is rotated R31 to point at 0
# The dial is rotated L48 to point at 52
# The dial is rotated L36 to point at 16
# The dial is rotated R84 to point at 0
# The dial is rotated R29 to point at 29
# The dial is rotated L29 to point at 0
# The dial is rotated L97 to point at 3
# The dial is rotated R85 to point at 88
# The dial is rotated R70 to point at 58, during this rotation the dial points at zero 1 times
# The dial is rotated R30 to point at 88
# The dial is rotated R12 to point at 0
# The dial is rotated L87 to point at 13
# The dial is rotated R224 to point at 37
# The dial is rotated R63 to point at 0
# The dial is rotated L35 to point at 65
# The dial is rotated L65 to point at 0
# The dial is rotated R76 to point at 76
# The dial is rotated L176 to point at 0
# The dial is rotated L40 to point at 60
# The dial is rotated L60 to point at 0
# The dial is rotated R30 to point at 30
# The dial is rotated L39 to point at 91, during this rotation the dial points at zero 1 times
# The dial is rotated L91 to point at 0
# The dial is rotated L23 to point at 77
# The dial is rotated R23 to point at 0
# The dial is rotated L82 to point at 18
# The dial is rotated R782 to point at 0
# The dial is rotated R977 to point at 77
# The dial is rotated L40 to point at 37
# The dial is rotated R44 to point at 81
# The dial is rotated L60 to point at 21
# The dial is rotated R49 to point at 70
# The dial is rotated L486 to point at 84, during this rotation the dial points at zero 1 times
# The dial is rotated L36 to point at 48
# The dial is rotated L778 to point at 70, during this rotation the dial points at zero 1 times
# The dial is rotated L70 to point at 0
# The dial is rotated R45 to point at 45
# The dial is rotated R93 to point at 38, during this rotation the dial points at zero 1 times
# The dial is rotated L38 to point at 0
# The dial is rotated L99 to point at 1
# The dial is rotated L66 to point at 35, during this rotation the dial points at zero 1 times
# The dial is rotated R28 to point at 63
# The dial is rotated L34 to point at 29
# The dial is rotated R71 to point at 0
# The dial is rotated L419 to point at 81
# The dial is rotated R81 to point at 62, during this rotation the dial points at zero 1 times
# The dial is rotated R38 to point at 0
# The dial is rotated L37 to point at 63
# The dial is rotated R80 to point at 43, during this rotation the dial points at zero 1 times
# The dial is rotated L43 to point at 0
# The dial is rotated R75 to point at 75
# The dial is rotated L13 to point at 62
# The dial is rotated R38 to point at 0
# The dial is rotated L19 to point at 81
# The dial is rotated R102 to point at 83
# The dial is rotated L83 to point at 0
# The dial is rotated L58 to point at 42
# The dial is rotated L10 to point at 32
# The dial is rotated R257 to point at 89
# The dial is rotated R711 to point at 0
# The dial is rotated L44 to point at 56
# The dial is rotated L22 to point at 34
# The dial is rotated L34 to point at 0
# The dial is rotated R52 to point at 52
# The dial is rotated L59 to point at 93, during this rotation the dial points at zero 1 times
# The dial is rotated R815 to point at 8, during this rotation the dial points at zero 1 times
# The dial is rotated R592 to point at 0
# The dial is rotated L297 to point at 3
# The dial is rotated R97 to point at 0
# The dial is rotated L66 to point at 34
# The dial is rotated R30 to point at 64
# The dial is rotated R99 to point at 63, during this rotation the dial points at zero 1 times
# The dial is rotated L835 to point at 28
# The dial is rotated L73 to point at 55, during this rotation the dial points at zero 1 times
# The dial is rotated L55 to point at 0
# The dial is rotated R982 to point at 82
# The dial is rotated L44 to point at 38
# The dial is rotated R62 to point at 0
# The dial is rotated R56 to point at 56
# The dial is rotated L6 to point at 50
# The dial is rotated R916 to point at 66
# The dial is rotated L64 to point at 2
# The dial is rotated R14 to point at 16
# The dial is rotated R899 to point at 15, during this rotation the dial points at zero 1 times
# The dial is rotated L42 to point at 73, during this rotation the dial points at zero 1 times
# The dial is rotated L73 to point at 0
# The dial is rotated R258 to point at 58
# The dial is rotated R42 to point at 0
# The dial is rotated R320 to point at 20
# The dial is rotated L184 to point at 36, during this rotation the dial points at zero 1 times
# The dial is rotated L3 to point at 33
# The dial is rotated L76 to point at 57, during this rotation the dial points at zero 1 times
# The dial is rotated L98 to point at 59, during this rotation the dial points at zero 1 times
# The dial is rotated R41 to point at 0
# The dial is rotated R42 to point at 42
# The dial is rotated L42 to point at 0
# The dial is rotated R25 to point at 25
# The dial is rotated R22 to point at 47
# The dial is rotated R53 to point at 0
# The dial is rotated R25 to point at 25
# The dial is rotated L25 to point at 0
# The dial is rotated R79 to point at 79
# The dial is rotated L361 to point at 18
# The dial is rotated L18 to point at 0
# The dial is rotated R40 to point at 40
# The dial is rotated L40 to point at 0
# The dial is rotated R70 to point at 70
# The dial is rotated L70 to point at 0
# The dial is rotated L3 to point at 97
# The dial is rotated R65 to point at 62, during this rotation the dial points at zero 1 times
# The dial is rotated R17 to point at 79
# The dial is rotated L88 to point at 91, during this rotation the dial points at zero 1 times
# The dial is rotated L76 to point at 15
# The dial is rotated R85 to point at 0
# The dial is rotated R21 to point at 21
# The dial is rotated L21 to point at 0
# The dial is rotated R17 to point at 17
# The dial is rotated R96 to point at 13, during this rotation the dial points at zero 1 times
# The dial is rotated R24 to point at 37
# The dial is rotated R63 to point at 0
# The dial is rotated R15 to point at 15
# The dial is rotated L15 to point at 0
# The dial is rotated R90 to point at 90
# The dial is rotated L90 to point at 0
# The dial is rotated R98 to point at 98
# The dial is rotated L3 to point at 95
# The dial is rotated R87 to point at 82, during this rotation the dial points at zero 1 times
# The dial is rotated R37 to point at 19, during this rotation the dial points at zero 1 times
# The dial is rotated L70 to point at 49, during this rotation the dial points at zero 1 times
# The dial is rotated L49 to point at 0
# The dial is rotated L94 to point at 6
# The dial is rotated R94 to point at 0
# The dial is rotated R93 to point at 93
# The dial is rotated L93 to point at 0
# The dial is rotated R81 to point at 81
# The dial is rotated L81 to point at 0
# The dial is rotated L26 to point at 74
# The dial is rotated L74 to point at 0
# The dial is rotated L40 to point at 60
# The dial is rotated L24 to point at 36
# The dial is rotated R63 to point at 99
# The dial is rotated R1 to point at 0
# The dial is rotated R44 to point at 44
# The dial is rotated R56 to point at 0
# The dial is rotated R3 to point at 3
# The dial is rotated L10 to point at 93, during this rotation the dial points at zero 1 times
# The dial is rotated L44 to point at 49
# The dial is rotated L57 to point at 92, during this rotation the dial points at zero 1 times
# The dial is rotated R10 to point at 2, during this rotation the dial points at zero 1 times
# The dial is rotated L83 to point at 19, during this rotation the dial points at zero 1 times
# The dial is rotated R51 to point at 70
# The dial is rotated R76 to point at 46, during this rotation the dial points at zero 1 times
# The dial is rotated R54 to point at 0
# The dial is rotated L69 to point at 31
# The dial is rotated L27 to point at 4
# The dial is rotated L4 to point at 0
# The dial is rotated L26 to point at 74
# The dial is rotated L32 to point at 42
# The dial is rotated L39 to point at 3
# The dial is rotated L24 to point at 79, during this rotation the dial points at zero 1 times
# The dial is rotated L13 to point at 66
# The dial is rotated L42 to point at 24
# The dial is rotated R27 to point at 51
# The dial is rotated L26 to point at 25
# The dial is rotated L4 to point at 21
# The dial is rotated R22 to point at 43
# The dial is rotated L50 to point at 93, during this rotation the dial points at zero 1 times
# The dial is rotated R18 to point at 11, during this rotation the dial points at zero 1 times
# The dial is rotated L13 to point at 98, during this rotation the dial points at zero 1 times
# The dial is rotated R43 to point at 41, during this rotation the dial points at zero 1 times
# The dial is rotated R24 to point at 65
# The dial is rotated R28 to point at 93
# The dial is rotated L24 to point at 69
# The dial is rotated R45 to point at 14, during this rotation the dial points at zero 1 times
# The dial is rotated L17 to point at 97, during this rotation the dial points at zero 1 times
# The dial is rotated L19 to point at 78
# The dial is rotated L22 to point at 56
# The dial is rotated R39 to point at 95
# The dial is rotated R44 to point at 39, during this rotation the dial points at zero 1 times
# The dial is rotated L4 to point at 35
# The dial is rotated R42 to point at 77
# The dial is rotated L20 to point at 57
# The dial is rotated L26 to point at 31
# The dial is rotated L49 to point at 82, during this rotation the dial points at zero 1 times
# The dial is rotated L28 to point at 54
# The dial is rotated R30 to point at 84
# The dial is rotated L10 to point at 74
# The dial is rotated L29 to point at 45
# The dial is rotated R6 to point at 51
# The dial is rotated R26 to point at 77
# The dial is rotated L28 to point at 49
# The dial is rotated L34 to point at 15
# The dial is rotated R14 to point at 29
# The dial is rotated L28 to point at 1
# The dial is rotated L28 to point at 73, during this rotation the dial points at zero 1 times
# The dial is rotated R6 to point at 79
# The dial is rotated R23 to point at 2, during this rotation the dial points at zero 1 times
# The dial is rotated L28 to point at 74, during this rotation the dial points at zero 1 times
# The dial is rotated R33 to point at 7, during this rotation the dial points at zero 1 times
# The dial is rotated L19 to point at 88, during this rotation the dial points at zero 1 times
# The dial is rotated R6 to point at 94
# The dial is rotated L22 to point at 72
# The dial is rotated R42 to point at 14, during this rotation the dial points at zero 1 times
# The dial is rotated L14 to point at 0
# The dial is rotated L41 to point at 59
# The dial is rotated L5 to point at 54
# we had 5575 zeros during spinning
# We have 1195 zeros visited
# We have had 6770 clicks ending on 0 total
